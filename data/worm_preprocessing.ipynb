# %% [markdown]
# <a href="https://colab.research.google.com/github/hmsch/porcelan/blob/main/data/worm_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Download data

# %%
# !wget 'https://www.ncbi.nlm.nih.gov/geo/download/?acc=GSE126954&format=file&file=GSE126954%5Fcell%5Fannotation%2Ecsv%2Egz' -O porcelan/data/GSE126954_cell_annotation.csv.gz
# !gunzip porcelan/data/GSE126954_cell_annotation.csv.gz

# !wget 'https://www.ncbi.nlm.nih.gov/geo/download/?acc=GSE126954&format=file&file=GSE126954%5Fgene%5Fannotation%2Ecsv%2Egz' -O porcelan/data/GSE126954_gene_annotation.csv.gz
# !gunzip porcelan/data/GSE126954_gene_annotation.csv.gz

# !wget 'https://www.ncbi.nlm.nih.gov/geo/download/?acc=GSE126954&format=file&file=GSE126954%5Fgene%5Fby%5Fcell%5Fcount%5Fmatrix%2Etxt%2Egz' -O porcelan/data/GSE126954_gene_by_cell_count_matrix.txt.gz
# !gunzip porcelan/data/GSE126954_gene_by_cell_count_matrix.txt.gz

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import pickle as pk
from ete3 import Tree
import dendropy
from scipy.io import mmread
import matplotlib.pyplot as plt

# %cd porcelan/
data_path = './data'
# Out:
# /home/hschlueter/porcelan

# %% [markdown]
# # Create aggregate worm
#
# Create aggregate worm by grouping cells from multiple individuals by lineage annotation and averaging gene expression profiles.
#
# Only keep leaf cells.
#
# Note: ordering of leaves matters -- here we sort alphabetically.

# %%
# full lineage tree
etree = Tree(f'{data_path}/celegans_1.nwk', format=1)
node_labels = np.array([n.name for n in etree.iter_search_nodes()])
print(etree.get_ascii())
# Out:
#                                                              /-ABALAAAALAL
#                                                    /ABALAAAALA
#                                                   |          \-ABALAAAALAR
#                                           /ABALAAAAL
#                                          |        |          /-ABALAAAALPA
#                                          |         \ABALAAAALP
#                                          |                   \-ABALAAAALPP
#                                   /ABALAAAA
#                                  |       |                   /-ABALAAAARLA
#                                  |       |         /ABALAAAARL
#                                  |       |        |          \-ABALAAAARLP
#                                  |        \ABALAAAAR
#                                  |                |          /-ABALAAAARRA
#                                  |                 \ABALAAAARR
#                                  |                           \-ABALAAAARRP
#                            /ABALAAA
#                           |      |                           /-ABALAAAPALL
#                           |      |                 /ABALAAAPAL
#                           |      |                |          \-ABALAAAPALR
#                           |      |        /ABALAAAPA
#                           |      |       |        |          /-ABALAAAPARL
#                           |      |       |         \ABALAAAPAR
#                           |      |       |                   \-ABALAAAPARR
#                           |       \ABALAAAP
#                           |              |                   /-ABALAAAPPLL
#                           |              |         /ABALAAAPPL
#                           |              |        |          \-ABALAAAPPLR
#                           |               \ABALAAAPP
#                           |                       |          /-ABALAAAPPRL
#                      /ABALAA                       \ABALAAAPPR
#                     |     |                                  \-ABALAAAPPRR
#                     |     |
#                     |     |                                  /-ABALAAPAAAL
#                     |     |                        /ABALAAPAAA
#                     |     |                       |          \-ABALAAPAAAR
#                     |     |               /ABALAAPAA
#                     |     |              |        |          /-ABALAAPAAPA
#                     |     |              |         \ABALAAPAAP
#                     |     |       /ABALAAPA                  \-ABALAAPAAPP
#                     |     |      |       |
#                     |     |      |       |         /-ABALAAPAPA
#                     |     |      |        \ABALAAPAP
#                     |     |      |                |          /-ABALAAPAPPA
#                     |     |      |                 \ABALAAPAPP
#                     |      \ABALAAP                          \-ABALAAPAPPP
#                     |            |
#                     |            |                 /-ABALAAPPAA
#                     |            |        /ABALAAPPA
#                     |            |       |        |          /-ABALAAPPAPA
#                     |            |       |         \ABALAAPPAP
#                     |            |       |                   \-ABALAAPPAPP
#                     |             \ABALAAPP
#                     |                    |                   /-ABALAAPPPAA
#                     |                    |         /ABALAAPPPA
#                     |                    |        |          \-ABALAAPPPAP
#                     |                     \ABALAAPPP
#                     |                             |                     /-ABALAAPPPPAA
#                     |                             |          /ABALAAPPPPA
#                     |                              \ABALAAPPPP          \-ABALAAPPPPAP
#                     |                                       |
#                     |                                        \-ABALAAPPPPP
#                 /ABALA
#                |    |                                        /-ABALAPAAAAA
#                |    |                              /ABALAPAAAA
#                |    |                             |          \-ABALAPAAAAP
#                |    |                     /ABALAPAAA
#                |    |                    |        |          /-ABALAPAAAPA
#                |    |                    |         \ABALAPAAAP
#                |    |                    |                   \-ABALAPAAAPP
#                |    |             /ABALAPAA
#                |    |            |       |                   /-ABALAPAAPAA
#                |    |            |       |         /ABALAPAAPA
#                |    |            |       |        |          \-ABALAPAAPAP
#                |    |            |        \ABALAPAAP
#                |    |            |                |                     /-ABALAPAAPPAA
#                |    |            |                |          /ABALAPAAPPA
#                |    |            |                 \ABALAPAAPP          \-ABALAPAAPPAP
#                |    |            |                          |
#                |    |      /ABALAPA                          \-ABALAPAAPPP
#                |    |     |      |
#                |    |     |      |                 /-ABALAPAPAA
#                |    |     |      |                |
#                |    |     |      |        /ABALAPAPA                    /-ABALAPAPAPAA
#                |    |     |      |       |        |          /ABALAPAPAPA
#                |    |     |      |       |         \ABALAPAPAP          \-ABALAPAPAPAP
#                |    |     |      |       |                  |
#                |    |     |      |       |                   \-ABALAPAPAPP
#                |    |     |       \ABALAPAP
#                |    |     |              |                              /-ABALAPAPPAAA
#                |    |     |              |                   /ABALAPAPPAA
#                |    |     |              |         /ABALAPAPPA          \-ABALAPAPPAAP
#                |    |     |              |        |         |
#                |    |     |               \ABALAPAPP         \-ABALAPAPPAP
#                |    |     |                       |
#                |     \ABALAP                      |          /-ABALAPAPPPA
#                |          |                        \ABALAPAPPP
#                |          |                                  \-ABALAPAPPPP
#                |          |
#                |          |                        /-ABALAPPAAA
#                |          |               /ABALAPPAA
#                |          |              |        |          /-ABALAPPAAPA
#                |          |              |         \ABALAPPAAP
#                |          |              |                   \-ABALAPPAAPP
#                |          |       /ABALAPPA
#                |          |      |       |                   /-ABALAPPAPAA
#                |          |      |       |         /ABALAPPAPA
#                |          |      |       |        |          \-ABALAPPAPAP
#                |          |      |        \ABALAPPAP
#                |          |      |                |          /-ABALAPPAPPA
#                |          |      |                 \ABALAPPAPP
#                |          |      |                           \-ABALAPPAPPP
#                |           \ABALAPP
#                |                 |                           /-ABALAPPPAAA
#                |                 |                 /ABALAPPPAA
#                |                 |                |          \-ABALAPPPAAP
#                |                 |        /ABALAPPPA
#                |                 |       |        |                     /-ABALAPPPAPAA
#                |                 |       |        |          /ABALAPPPAPA
#                |                 |       |         \ABALAPPPAP          \-ABALAPPPAPAP
#                |                 |       |                  |
#                |                  \ABALAPPP                  \-ABALAPPPAPP
#                |                         |
#                |                         |                              /-ABALAPPPPAAA
#                |                         |                   /ABALAPPPPAA
#                |                         |         /ABALAPPPPA          \-ABALAPPPPAAP
#                |                         |        |         |
#                |                          \ABALAPPPP         \-ABALAPPPPAP
#                |                                  |
#             /ABAL                                 |          /-ABALAPPPPPA
#            |   |                                   \ABALAPPPPP
#            |   |                                             \-ABALAPPPPPP
#            |   |
#            |   |                                             /-ABALPAAAAAA
#            |   |                                   /ABALPAAAAA
#            |   |                                  |          \-ABALPAAAAAP
#            |   |                          /ABALPAAAA
#            |   |                         |        |          /-ABALPAAAAPA
#            |   |                         |         \ABALPAAAAP
#            |   |                         |                   \-ABALPAAAAPP
#            |   |                  /ABALPAAA
#            |   |                 |       |                   /-ABALPAAAPAA
#            |   |                 |       |         /ABALPAAAPA
#            |   |                 |       |        |          \-ABALPAAAPAP
#            |   |                 |        \ABALPAAAP
#            |   |                 |                |          /-ABALPAAAPPA
#            |   |                 |                 \ABALPAAAPP
#            |   |                 |                           \-ABALPAAAPPP
#            |   |           /ABALPAA
#            |   |          |      |                           /-ABALPAAPAAA
#            |   |          |      |                 /ABALPAAPAA
#            |   |          |      |                |          \-ABALPAAPAAP
#            |   |          |      |        /ABALPAAPA
#            |   |          |      |       |        |          /-ABALPAAPAPA
#            |   |          |      |       |         \ABALPAAPAP
#            |   |          |      |       |                   \-ABALPAAPAPP
#            |   |          |       \ABALPAAP
#            |   |          |              |                   /-ABALPAAPPAA
#            |   |          |              |         /ABALPAAPPA
#            |   |          |              |        |          \-ABALPAAPPAP
#            |   |          |               \ABALPAAPP
#            |   |          |                       |          /-ABALPAAPPPA
#            |   |          |                        \ABALPAAPPP
#            |   |          |                                  \-ABALPAAPPPP
#            |   |     /ABALPA
#            |   |    |     |                                  /-ABALPAPAAAA
#            |   |    |     |                        /ABALPAPAAA
#            |   |    |     |                       |          \-ABALPAPAAAP
#            |   |    |     |               /ABALPAPAA
#            |   |    |     |              |        |          /-ABALPAPAAPA
#            |   |    |     |              |         \ABALPAPAAP
#            |   |    |     |              |                   \-ABALPAPAAPP
#            |   |    |     |       /ABALPAPA
#            |   |    |     |      |       |                   /-ABALPAPAPAA
#            |   |    |     |      |       |         /ABALPAPAPA
#            |   |    |     |      |       |        |         |           /-ABALPAPAPAPA
#            |   |    |     |      |       |        |          \ABALPAPAPAP
#            |   |    |     |      |        \ABALPAPAP                    \-ABALPAPAPAPP
#            |   |    |     |      |                |
#            |   |    |     |      |                |          /-ABALPAPAPPA
#            |   |    |     |      |                 \ABALPAPAPP
#            |   |    |      \ABALPAP                          \-ABALPAPAPPP
#            |   |    |            |
#            |   |    |            |                           /-ABALPAPPAAA
#            |   |    |            |                 /ABALPAPPAA
#            |   |    |            |                |         |           /-ABALPAPPAAPA
#            |   |    |            |                |          \ABALPAPPAAP
#            |   |    |            |        /ABALPAPPA                    \-ABALPAPPAAPP
#            |   |    |            |       |        |
#            |   |    |            |       |        |          /-ABALPAPPAPA
#            |   |    |            |       |         \ABALPAPPAP
#            |   |    |             \ABALPAPP                  \-ABALPAPPAPP
#            |   |    |                    |
#            |   |    |                    |                   /-ABALPAPPPAA
#            |   |    |                    |         /ABALPAPPPA
#            |   |    |                    |        |          \-ABALPAPPPAP
#            |    \ABALP                    \ABALPAPPP
#            |        |                             |          /-ABALPAPPPPA
#            |        |                              \ABALPAPPPP
#            |        |                                        \-ABALPAPPPPP
#            |        |
#            |        |                              /-ABALPPAAAA
#            |        |                     /ABALPPAAA
#            |        |                    |        |          /-ABALPPAAAPA
#            |        |                    |         \ABALPPAAAP
#            |        |             /ABALPPAA                  \-ABALPPAAAPP
#            |        |            |       |
#            |        |            |       |         /-ABALPPAAPA
#            |        |            |        \ABALPPAAP
#            |        |            |                |          /-ABALPPAAPPA
#            |        |            |                 \ABALPPAAPP
#            |        |            |                           \-ABALPPAAPPP
#            |        |      /ABALPPA
#            |        |     |      |                           /-ABALPPAPAAA
#            |        |     |      |                 /ABALPPAPAA
#            |        |     |      |                |          \-ABALPPAPAAP
#            |        |     |      |        /ABALPPAPA
#            |        |     |      |       |        |          /-ABALPPAPAPA
#            |        |     |      |       |         \ABALPPAPAP
#            |        |     |      |       |                   \-ABALPPAPAPP
#            |        |     |       \ABALPPAP
#            |        |     |              |                   /-ABALPPAPPAA
#            |        |     |              |         /ABALPPAPPA
#            |        |     |              |        |          \-ABALPPAPPAP
#            |        |     |               \ABALPPAPP
#            |        |     |                       |                     /-ABALPPAPPPAA
#            |        |     |                       |          /ABALPPAPPPA
#            |        |     |                        \ABALPPAPPP          \-ABALPPAPPPAP
#            |        |     |                                 |
#            |         \ABALPP                                 \-ABALPPAPPPP
#            |              |
#            |              |                                  /-ABALPPPAAAA
#            |              |                        /ABALPPPAAA
#            |              |                       |          \-ABALPPPAAAP
#            |              |               /ABALPPPAA
#            |              |              |        |          /-ABALPPPAAPD
#            |              |              |         \ABALPPPAAP
#            |              |              |                   \-ABALPPPAAPV
#            |              |       /ABALPPPA
#            |              |      |       |                   /-ABALPPPAPAD
#            |              |      |       |         /ABALPPPAPA
#            |              |      |       |        |          \-ABALPPPAPAV
#            |              |      |        \ABALPPPAP
#            |              |      |                |          /-ABALPPPAPPA
#            |              |      |                 \ABALPPPAPP
#            |              |      |                          |           /-ABALPPPAPPPA
#            |              |      |                           \ABALPPPAPPP
#            |               \ABALPPP                                     \-ABALPPPAPPPP
#            |                     |
#            |                     |                           /-ABALPPPPAAD
#            |                     |                 /ABALPPPPAA
#            |                     |                |          \-ABALPPPPAAV
#            |                     |        /ABALPPPPA
#            |                     |       |        |                     /-ABALPPPPAPAA
#            |                     |       |        |          /ABALPPPPAPA
#            |                     |       |         \ABALPPPPAP          \-ABALPPPPAPAP
#            |                     |       |                  |
#            |                      \ABALPPPP                  \-ABALPPPPAPP
#            |                             |
#            |                             |                   /-ABALPPPPPAA
#          /ABA                            |         /ABALPPPPPA
#         |  |                             |        |          \-ABALPPPPPAP
#         |  |                             |        |
#         |  |                              \ABALPPPPP                    /-ABALPPPPPPAA
#         |  |                                      |          /ABALPPPPPPA
#         |  |                                      |         |           \-ABALPPPPPPAP
#         |  |                                       \ABALPPPPPP
#         |  |                                                |           /-ABALPPPPPPPA
#         |  |                                                 \ABALPPPPPPP
#         |  |                                                            \-ABALPPPPPPPP
#         |  |
#         |  |                                                 /-ABARAAAAAAA
#         |  |                                       /ABARAAAAAA
#         |  |                                      |          \-ABARAAAAAAP
#         |  |                              /ABARAAAAA
#         |  |                             |        |          /-ABARAAAAAPA
#         |  |                             |         \ABARAAAAAP
#         |  |                      /ABARAAAA                  \-ABARAAAAAPP
#         |  |                     |       |
#         |  |                     |       |                   /-ABARAAAAPAA
#         |  |                     |       |         /ABARAAAAPA
#         |  |                     |        \ABARAAAAP         \-ABARAAAAPAP
#         |  |                     |                |
#         |  |                     |                 \-ABARAAAAPP
#         |  |               /ABARAAA
#         |  |              |      |                           /-ABARAAAPAAA
#         |  |              |      |                 /ABARAAAPAA
#         |  |              |      |                |          \-ABARAAAPAAP
#         |  |              |      |        /ABARAAAPA
#         |  |              |      |       |        |          /-ABARAAAPAPA
#         |  |              |      |       |         \ABARAAAPAP
#         |  |              |      |       |                   \-ABARAAAPAPP
#         |  |              |       \ABARAAAP
#         |  |              |              |                   /-ABARAAAPPAA
#         |  |              |              |         /ABARAAAPPA
#         |  |              |              |        |          \-ABARAAAPPAP
#         |  |              |               \ABARAAAPP
#         |  |              |                       |          /-ABARAAAPPPA
#         |  |              |                        \ABARAAAPPP
#         |  |              |                                  \-ABARAAAPPPP
#         |  |         /ABARAA
#         |  |        |     |                                  /-ABARAAPAAAA
#         |  |        |     |                        /ABARAAPAAA
#         |  |        |     |                       |          \-ABARAAPAAAP
#         |  |        |     |               /ABARAAPAA
#         |  |        |     |              |        |          /-ABARAAPAAPA
#         |  |        |     |              |         \ABARAAPAAP
#         |  |        |     |              |                   \-ABARAAPAAPP
#         |  |        |     |       /ABARAAPA
#         |  |        |     |      |       |                              /-ABARAAPAPAAD
#         |  |        |     |      |       |                   /ABARAAPAPAA
#         |  |        |     |      |       |         /ABARAAPAPA          \-ABARAAPAPAAV
#         |  |        |     |      |       |        |         |
#         |  |        |     |      |        \ABARAAPAP         \-ABARAAPAPAP
#         |  |        |     |      |                |
#         |  |        |     |      |                |          /-ABARAAPAPPA
#         |  |        |     |      |                 \ABARAAPAPP
#         |  |        |      \ABARAAP                          \-ABARAAPAPPP
#         |  |        |            |
#         |  |        |            |                           /-ABARAAPPAAA
#         |  |        |            |                 /ABARAAPPAA
#         |  |        |            |                |          \-ABARAAPPAAP
#         |  |        |            |        /ABARAAPPA
#         |  |        |            |       |        |          /-ABARAAPPAPA
#         |  |        |            |       |         \ABARAAPPAP
#         |  |        |            |       |                   \-ABARAAPPAPP
#         |  |        |             \ABARAAPP
#         |  |        |                    |                              /-ABARAAPPPAAD
#         |  |        |                    |                   /ABARAAPPPAA
#         |  |        |                    |         /ABARAAPPPA          \-ABARAAPPPAAV
#         |  |        |                    |        |         |
#         |  |        |                     \ABARAAPPP         \-ABARAAPPPAP
#         |  |        |                             |
#         |  |        |                             |          /-ABARAAPPPPA
#         |  |    /ABARA                             \ABARAAPPPP
#         |  |   |    |                                        \-ABARAAPPPPP
#         |  |   |    |
#         |  |   |    |                                        /-ABARAPAAAAA
#         |  |   |    |                              /ABARAPAAAA
#         |  |   |    |                             |          \-ABARAPAAAAP
#         |  |   |    |                     /ABARAPAAA
#         |  |   |    |                    |        |          /-ABARAPAAAPA
#         |  |   |    |                    |         \ABARAPAAAP
#         |  |   |    |                    |                   \-ABARAPAAAPP
#         |  |   |    |             /ABARAPAA
#         |  |   |    |            |       |                   /-ABARAPAAPAA
#         |  |   |    |            |       |         /ABARAPAAPA
#         |  |   |    |            |       |        |          \-ABARAPAAPAP
#         |  |   |    |            |        \ABARAPAAP
#         |  |   |    |            |                |          /-ABARAPAAPPA
#         |  |   |    |            |                 \ABARAPAAPP
#         |  |   |    |            |                           \-ABARAPAAPPP
#         |  |   |    |      /ABARAPA
#         |  |   |    |     |      |                           /-ABARAPAPAAA
#         |  |   |    |     |      |                 /ABARAPAPAA
#         |  |   |    |     |      |                |         |           /-ABARAPAPAAPA
#         |  |   |    |     |      |                |          \ABARAPAPAAP
#         |  |   |    |     |      |        /ABARAPAPA                    \-ABARAPAPAAPP
#         |  |   |    |     |      |       |        |
#         |  |   |    |     |      |       |        |          /-ABARAPAPAPA
#         |  |   |    |     |      |       |         \ABARAPAPAP
#         |  |   |    |     |       \ABARAPAP                  \-ABARAPAPAPP
#         |  |   |    |     |              |
#         |  |   |    |     |              |                   /-ABARAPAPPAA
#         |  |   |    |     |              |         /ABARAPAPPA
#         |  |   |    |     |              |        |          \-ABARAPAPPAP
#         |  |   |    |     |               \ABARAPAPP
#         |  |   |    |     |                       |          /-ABARAPAPPPA
#         |  |   |    |     |                        \ABARAPAPPP
#         |  |   |     \ABARAP                                 \-ABARAPAPPPP
#         |  |   |          |
#         |  |   |          |                                  /-ABARAPPAAAA
#         |  |   |          |                        /ABARAPPAAA
#         |  |   |          |                       |          \-ABARAPPAAAP
#         |  |   |          |               /ABARAPPAA
#         |  |   |          |              |        |          /-ABARAPPAAPA
#         |  |   |          |              |         \ABARAPPAAP
#         |  |   |          |              |                   \-ABARAPPAAPP
#         |  |   |          |       /ABARAPPA
#         |  |   |          |      |       |                   /-ABARAPPAPAA
#         |  |   |          |      |       |         /ABARAPPAPA
#         |  |   |          |      |       |        |         |           /-ABARAPPAPAPA
#         |  |   |          |      |       |        |          \ABARAPPAPAP
#         |  |   |          |      |        \ABARAPPAP                    \-ABARAPPAPAPP
#         |  |   |          |      |                |
#         |  |   |          |      |                |          /-ABARAPPAPPA
#         |  |   |          |      |                 \ABARAPPAPP
#         |  |   |           \ABARAPP                          \-ABARAPPAPPP
#         |  |   |                 |
#         |  |   |                 |                           /-ABARAPPPAAA
#         |  |   |                 |                 /ABARAPPPAA
#         |   \ABAR                |                |          \-ABARAPPPAAP
#         |      |                 |        /ABARAPPPA
#         |      |                 |       |        |          /-ABARAPPPAPA
#         |      |                 |       |         \ABARAPPPAP
#         |      |                 |       |                   \-ABARAPPPAPP
#         |      |                  \ABARAPPP
#         |      |                         |                   /-ABARAPPPPAA
#         |      |                         |         /ABARAPPPPA
#         |      |                         |        |          \-ABARAPPPPAP
#         |      |                          \ABARAPPPP
#         |      |                                  |                     /-ABARAPPPPPAA
#         |      |                                  |          /ABARAPPPPPA
#         |      |                                   \ABARAPPPPP          \-ABARAPPPPPAP
#         |      |                                            |
#         |      |                                             \-ABARAPPPPPP
#         |      |
#         |      |                                             /-ABARPAAAAAL
#         |      |                                   /ABARPAAAAA
#         |      |                                  |          \-ABARPAAAAAR
#         |      |                          /ABARPAAAA
#         |      |                         |        |          /-ABARPAAAAPA
#         |      |                         |         \ABARPAAAAP
#         |      |                  /ABARPAAA                  \-ABARPAAAAPP
#         |      |                 |       |
#         |      |                 |       |                   /-ABARPAAAPAA
#         |      |                 |       |         /ABARPAAAPA
#         |      |                 |        \ABARPAAAP         \-ABARPAAAPAP
#         |      |           /ABARPAA               |
#         |      |          |      |                 \-ABARPAAAPP
#         |      |          |      |
#         |      |          |      |                 /-ABARPAAPAA
#         |      |          |      |        /ABARPAAPA
#         |      |          |      |       |         \-ABARPAAPAP
#         |      |          |       \ABARPAAP
#         |      |          |              |         /-ABARPAAPPA
#         |      |          |               \ABARPAAPP
#         |      |          |                        \-ABARPAAPPP
#         |      |          |
#         |      |     /ABARPA                                 /-ABARPAPAAAA
#         |      |    |     |                        /ABARPAPAAA
#         |      |    |     |                       |          \-ABARPAPAAAP
#         |      |    |     |               /ABARPAPAA
#         |      |    |     |              |        |          /-ABARPAPAAPA
#         |      |    |     |              |         \ABARPAPAAP
#         |      |    |     |              |                  |           /-ABARPAPAAPPA
#         |      |    |     |       /ABARPAPA                  \ABARPAPAAPP
#         |      |    |     |      |       |                              \-ABARPAPAAPPP
#         |      |    |     |      |       |
#         |      |    |     |      |       |         /-ABARPAPAPA
#         |      |    |     |      |        \ABARPAPAP
#         |      |    |      \ABARPAP                \-ABARPAPAPP
#         |      |    |            |
#         |      |    |            |                 /-ABARPAPPAA
#         |      |    |            |        /ABARPAPPA
#         |      |    |            |       |         \-ABARPAPPAP
#         |      |    |             \ABARPAPP
#         |      |    |                    |         /-ABARPAPPPA
#         |       \ABARP                    \ABARPAPPP
#         |           |                              \-ABARPAPPPP
#         |           |
#         |           |                              /-ABARPPAAAA
#         |           |                     /ABARPPAAA
#         |           |                    |         \-ABARPPAAAP
#         |           |             /ABARPPAA
#         |           |            |       |         /-ABARPPAAPA
#         |           |            |        \ABARPPAAP
#         |           |            |                |          /-ABARPPAAPPA
#         |           |            |                 \ABARPPAAPP
#         |           |      /ABARPPA                          \-ABARPPAAPPP
#         |           |     |      |
#         |           |     |      |                 /-ABARPPAPAA
#         |           |     |      |        /ABARPPAPA
#         |           |     |      |       |         \-ABARPPAPAP
#         |           |     |       \ABARPPAP
#         |           |     |              |         /-ABARPPAPPA
#         |           |     |               \ABARPPAPP
#         |           |     |                        \-ABARPPAPPP
#         |            \ABARPP
#         |                 |                        /-ABARPPPAAA
#         |                 |               /ABARPPPAA
#         |                 |              |         \-ABARPPPAAP
#         |                 |       /ABARPPPA
#         |                 |      |       |         /-ABARPPPAPA
#         |                 |      |        \ABARPPPAP
#         |                 |      |                |          /-ABARPPPAPPA
#         |                 |      |                 \ABARPPPAPP
#         |                  \ABARPPP                          \-ABARPPPAPPP
#         |                        |
#         |                        |                 /-ABARPPPPAA
#         |                        |        /ABARPPPPA
#         |                        |       |         \-ABARPPPPAP
#         |                         \ABARPPPP
#         |                                |         /-ABARPPPPPA
#         |                                 \ABARPPPPP
#         |                                          \-ABARPPPPPP
#         |
#         |                                                    /-ABPLAAAAAAA
#       /P0A                                         /ABPLAAAAAA
#      |  |                                         |          \-ABPLAAAAAAP
#      |  |                                 /ABPLAAAAA
#      |  |                                |        |          /-ABPLAAAAAPA
#      |  |                                |         \ABPLAAAAAP
#      |  |                                |                  |           /-ABPLAAAAAPPA
#      |  |                         /ABPLAAAA                  \ABPLAAAAAPP
#      |  |                        |       |                              \-ABPLAAAAAPPP
#      |  |                        |       |
#      |  |                        |       |         /-ABPLAAAAPA
#      |  |                        |        \ABPLAAAAP
#      |  |                  /ABPLAAA                \-ABPLAAAAPP
#      |  |                 |      |
#      |  |                 |      |                 /-ABPLAAAPAA
#      |  |                 |      |        /ABPLAAAPA
#      |  |                 |      |       |         \-ABPLAAAPAP
#      |  |                 |       \ABPLAAAP
#      |  |                 |              |         /-ABPLAAAPPA
#      |  |                 |               \ABPLAAAPP
#      |  |                 |                        \-ABPLAAAPPP
#      |  |                 |
#      |  |                 |                                  /-ABPLAAPAAAA
#      |  |            /ABPLAA                       /ABPLAAPAAA
#      |  |           |     |               /ABPLAAPAA         \-ABPLAAPAAAP
#      |  |           |     |              |        |
#      |  |           |     |              |         \-ABPLAAPAAP
#      |  |           |     |       /ABPLAAPA
#      |  |           |     |      |       |                   /-ABPLAAPAPAA
#      |  |           |     |      |       |         /ABPLAAPAPA
#      |  |           |     |      |       |        |          \-ABPLAAPAPAP
#      |  |           |     |      |        \ABPLAAPAP
#      |  |           |     |      |                |          /-ABPLAAPAPPA
#      |  |           |     |      |                 \ABPLAAPAPP
#      |  |           |      \ABPLAAP                         |           /-ABPLAAPAPPPA
#      |  |           |            |                           \ABPLAAPAPPP
#      |  |           |            |                                      \-ABPLAAPAPPPP
#      |  |           |            |
#      |  |           |            |                 /-ABPLAAPPAA
#      |  |           |            |        /ABPLAAPPA
#      |  |           |            |       |         \-ABPLAAPPAP
#      |  |           |             \ABPLAAPP
#      |  |           |                    |         /-ABPLAAPPPA
#      |  |           |                     \ABPLAAPPP
#      |  |           |                              \-ABPLAAPPPP
#      |  |           |
#      |  |           |                                        /-ABPLAPAAAAA
#      |  |           |                              /ABPLAPAAAA
#      |  |       /ABPLA                            |         |           /-ABPLAPAAAAPA
#      |  |      |    |                             |          \ABPLAPAAAAP
#      |  |      |    |                     /ABPLAPAAA                    \-ABPLAPAAAAPP
#      |  |      |    |                    |        |
#      |  |      |    |                    |        |                     /-ABPLAPAAAPAD
#      |  |      |    |                    |        |          /ABPLAPAAAPA
#      |  |      |    |             /ABPLAPAA        \ABPLAPAAAP          \-ABPLAPAAAPAV
#      |  |      |    |            |       |                  |
#      |  |      |    |            |       |                   \-ABPLAPAAAPP
#      |  |      |    |            |       |
#      |  |      |    |            |       |         /-ABPLAPAAPA
#      |  |      |    |            |        \ABPLAPAAP
#      |  |      |    |      /ABPLAPA                \-ABPLAPAAPP
#      |  |      |    |     |      |
#      |  |      |    |     |      |                           /-ABPLAPAPAAA
#      |  |      |    |     |      |                 /ABPLAPAPAA
#      |  |      |    |     |      |        /ABPLAPAPA         \-ABPLAPAPAAP
#      |  |      |    |     |      |       |        |
#      |  |      |    |     |      |       |         \-ABPLAPAPAP
#      |  |      |    |     |       \ABPLAPAP
#      |  |      |    |     |              |         /-ABPLAPAPPA
#      |  |      |    |     |              |        |
#      |  |      |    |     |               \ABPLAPAPP         /-ABPLAPAPPPA
#      |  |      |    |     |                       |         |
#      |  |      |    |     |                        \ABPLAPAPPP                      /-ABPLAPAPPPPAA
#      |  |      |     \ABPLAP                                |           /ABPLAPAPPPPA
#      |  |      |          |                                  \ABPLAPAPPPP           \-ABPLAPAPPPPAP
#      |  |      |          |                                            |
#      |  |      |          |                                             \-ABPLAPAPPPPP
#      |  |      |          |
#      |  |      |          |                        /-ABPLAPPAAA
#      |  |      |          |               /ABPLAPPAA
#      |  |      |          |              |         \-ABPLAPPAAP
#      |  |      |          |       /ABPLAPPA
#      |  |      |          |      |       |         /-ABPLAPPAPA
#      |  |      |          |      |        \ABPLAPPAP
#      |  |      |          |      |                 \-ABPLAPPAPP
#      |  |      |          |      |
#      |  |      |          |      |                           /-ABPLAPPPAAA
#      |  |      |           \ABPLAPP                /ABPLAPPPAA
#      |  |      |                 |                |          \-ABPLAPPPAAP
#      |  |      |                 |        /ABPLAPPPA
#      |  |      |                 |       |        |          /-ABPLAPPPAPA
#      |  |      |                 |       |         \ABPLAPPPAP
#      |  |      |                 |       |                  |           /-ABPLAPPPAPPA
#      |  |      |                  \ABPLAPPP                  \ABPLAPPPAPP
#      |  |      |                         |                              \-ABPLAPPPAPPP
#      |  |      |                         |
#      |  |      |                         |         /-ABPLAPPPPA
#      |  |      |                          \ABPLAPPPP
#      |  |      |                                   \-ABPLAPPPPP
#      |  |      |
#      |  |      |                                             /-ABPLPAAAAAA
#      |  |      |                                   /ABPLPAAAAA
#      |  |      |                                  |          \-ABPLPAAAAAP
#      |  |      |                          /ABPLPAAAA
#      |  |      |                         |        |          /-ABPLPAAAAPA
#      |  |      |                         |         \ABPLPAAAAP
#      |  |   /ABPL                        |                   \-ABPLPAAAAPP
#      |  |  |   |                  /ABPLPAAA
#      |  |  |   |                 |       |                   /-ABPLPAAAPAA
#      |  |  |   |                 |       |         /ABPLPAAAPA
#      |  |  |   |                 |       |        |          \-ABPLPAAAPAP
#      |  |  |   |                 |        \ABPLPAAAP
#      |  |  |   |                 |                |                     /-ABPLPAAAPPAA
#      |  |  |   |                 |                |          /ABPLPAAAPPA
#      |  |  |   |                 |                 \ABPLPAAAPP          \-ABPLPAAAPPAP
#      |  |  |   |                 |                          |
#      |  |  |   |           /ABPLPAA                          \-ABPLPAAAPPP
#      |  |  |   |          |      |
#      |  |  |   |          |      |                           /-ABPLPAAPAAA
#      |  |  |   |          |      |                 /ABPLPAAPAA
#      |  |  |   |          |      |                |          \-ABPLPAAPAAP
#      |  |  |   |          |      |        /ABPLPAAPA
#      |  |  |   |          |      |       |        |          /-ABPLPAAPAPA
#      |  |  |   |          |      |       |         \ABPLPAAPAP
#      |  |  |   |          |      |       |                   \-ABPLPAAPAPP
#      |  |  |   |          |       \ABPLPAAP
#      |  |  |   |          |              |                   /-ABPLPAAPPAA
#      |  |  |   |          |              |         /ABPLPAAPPA
#      |  |  |   |          |              |        |          \-ABPLPAAPPAP
#      |  |  |   |          |               \ABPLPAAPP
#      |  |  |   |          |                       |          /-ABPLPAAPPPA
#      |  |  |   |          |                        \ABPLPAAPPP
#      |  |  |   |          |                                 |           /-ABPLPAAPPPPA
#      |  |  |   |     /ABPLPA                                 \ABPLPAAPPPP
#      |  |  |   |    |     |                                             \-ABPLPAAPPPPP
#      |  |  |   |    |     |
#      |  |  |   |    |     |                                  /-ABPLPAPAAAA
#      |  |  |   |    |     |                        /ABPLPAPAAA
#      |  |  |   |    |     |                       |          \-ABPLPAPAAAP
#      |  |  |   |    |     |               /ABPLPAPAA
#      |  |  |   |    |     |              |        |          /-ABPLPAPAAPA
#      |  |  |   |    |     |              |         \ABPLPAPAAP
#      |  |  |   |    |     |              |                   \-ABPLPAPAAPP
#      |  |  |   |    |     |       /ABPLPAPA
#      |  |  |   |    |     |      |       |                   /-ABPLPAPAPAA
#      |  |  |   |    |     |      |       |         /ABPLPAPAPA
#      |  |  |   |    |     |      |       |        |          \-ABPLPAPAPAP
#      |  |  |   |    |     |      |        \ABPLPAPAP
#      |  |  |   |    |     |      |                |          /-ABPLPAPAPPA
#      |  |  |   |    |     |      |                 \ABPLPAPAPP
#      |  |  |   |    |      \ABPLPAP                          \-ABPLPAPAPPP
#      |  |  |   |    |            |
#      |  |  |   |    |            |                           /-ABPLPAPPAAA
#      |  |  |   |    |            |                 /ABPLPAPPAA
#      |  |  |   |    |            |        /ABPLPAPPA         \-ABPLPAPPAAP
#      |  |  |   |    |            |       |        |
#      |  |  |   |    |            |       |         \-ABPLPAPPAP
#      |  |  |   |    |             \ABPLPAPP
#      |  |  |   |    |                    |                   /-ABPLPAPPPAA
#      |  |  |   |    |                    |         /ABPLPAPPPA
#      |  |  |   |    |                    |        |          \-ABPLPAPPPAP
#      |  |  |   |    |                     \ABPLPAPPP
#      |  |  |   |    |                             |          /-ABPLPAPPPPA
#      |  |  |   |    |                              \ABPLPAPPPP
#      |  |  |   |    |                                        \-ABPLPAPPPPP
#      |  |  |    \ABPLP
#      |  |  |        |                                        /-ABPLPPAAAAA
#      |  |  |        |                              /ABPLPPAAAA
#      |  |  |        |                             |         |           /-ABPLPPAAAAPA
#      |  |  |        |                     /ABPLPPAAA         \ABPLPPAAAAP
#      |  |  |        |                    |        |                     \-ABPLPPAAAAPP
#      |  |  |        |                    |        |
#      |  |  |        |                    |         \-ABPLPPAAAP
#      |  |  |        |             /ABPLPPAA
#      |  |  |        |            |       |                   /-ABPLPPAAPAA
#      |  |  |        |            |       |         /ABPLPPAAPA
#      |  |  |        |            |       |        |          \-ABPLPPAAPAP
#      |  |  |        |            |        \ABPLPPAAP
#      |  |  |        |            |                |          /-ABPLPPAAPPA
#      |  |  |        |            |                 \ABPLPPAAPP
#      |  |  |        |            |                           \-ABPLPPAAPPP
#      |  |  |        |      /ABPLPPA
#      |  |  |        |     |      |                                      /-ABPLPPAPAAAA
#      |  |  |        |     |      |                           /ABPLPPAPAAA
#      |  |  |        |     |      |                 /ABPLPPAPAA          \-ABPLPPAPAAAP
#      |  |  |        |     |      |                |         |
#      |  |  |        |     |      |        /ABPLPPAPA         \-ABPLPPAPAAP
#      |  |  |        |     |      |       |        |
#      |  |  |        |     |      |       |        |          /-ABPLPPAPAPA
#      |  |  |        |     |      |       |         \ABPLPPAPAP
#      |  |  |        |     |       \ABPLPPAP                  \-ABPLPPAPAPP
#      |  |  |        |     |              |
#      |  |  |        |     |              |                   /-ABPLPPAPPAA
#      |  |  |        |     |              |         /ABPLPPAPPA
#      |  |  |        |     |              |        |          \-ABPLPPAPPAP
#      |  |  |        |     |               \ABPLPPAPP
#      |  |  |        |     |                       |          /-ABPLPPAPPPA
#      |  |  |        |     |                        \ABPLPPAPPP
#      |  |  |         \ABPLPP                                 \-ABPLPPAPPPP
#      |  |  |              |
#      |  |  |              |                                  /-ABPLPPPAAAA
#      |  |  |              |                        /ABPLPPPAAA
#      |  |  |              |                       |          \-ABPLPPPAAAP
#      |  |  |              |               /ABPLPPPAA
#      |  |  |              |              |        |                     /-ABPLPPPAAPAA
#      |  |  |              |              |        |          /ABPLPPPAAPA
#      |  |  |              |              |         \ABPLPPPAAP          \-ABPLPPPAAPAP
#      |  |  |              |       /ABPLPPPA                 |
#      |  |  |              |      |       |                   \-ABPLPPPAAPP
#      |  |  |              |      |       |
#      |  |  |              |      |       |                   /-ABPLPPPAPAA
#      |  |  |              |      |       |         /ABPLPPPAPA
#      |  |  |              |      |        \ABPLPPPAP         \-ABPLPPPAPAP
#      |  |  |              |      |                |
#      |  |  |              |      |                 \-ABPLPPPAPP
#      |  |  |               \ABPLPPP
#      |  |  |                     |                           /-ABPLPPPPAAA
#      |  |  |                     |                 /ABPLPPPPAA
#      |  |  |                     |                |          \-ABPLPPPPAAP
#      |  |  |                     |        /ABPLPPPPA
#      |  |  |                     |       |        |          /-ABPLPPPPAPA
#      |  |  |                     |       |         \ABPLPPPPAP
#      |  |  |                     |       |                   \-ABPLPPPPAPP
#      |  |  |                      \ABPLPPPP
#      |  |  |                             |                   /-ABPLPPPPPAA
#      |  |  |                             |         /ABPLPPPPPA
#      |  |  |                             |        |          \-ABPLPPPPPAP
#      |  |  |                              \ABPLPPPPP
#      |  |  |                                      |          /-ABPLPPPPPPA
#      |  |  |                                       \ABPLPPPPPP
#      |   \ABP                                                \-ABPLPPPPPPP
#      |     |
#      |     |                                                 /-ABPRAAAAAAA
#      |     |                                       /ABPRAAAAAA
#      |     |                                      |          \-ABPRAAAAAAP
#      |     |                              /ABPRAAAAA
#      |     |                             |        |          /-ABPRAAAAAPD
#      |     |                             |         \ABPRAAAAAP
#      |     |                             |                   \-ABPRAAAAAPV
#      |     |                      /ABPRAAAA
#      |     |                     |       |                   /-ABPRAAAAPAD
#      |     |                     |       |         /ABPRAAAAPA
#      |     |                     |       |        |          \-ABPRAAAAPAV
#      |     |                     |        \ABPRAAAAP
#      |     |                     |                |          /-ABPRAAAAPPA
#      |     |                     |                 \ABPRAAAAPP
#      |     |                     |                          |           /-ABPRAAAAPPPA
#      |     |                     |                           \ABPRAAAAPPP
#      |     |               /ABPRAAA                                     \-ABPRAAAAPPPP
#      |     |              |      |
#      |     |              |      |                           /-ABPRAAAPAAD
#      |     |              |      |                 /ABPRAAAPAA
#      |     |              |      |                |          \-ABPRAAAPAAV
#      |     |              |      |        /ABPRAAAPA
# ...
#      |                           |       |         \ABPRPPPPAP
#      |                           |       |                   \-ABPRPPPPAPP
#      |                            \ABPRPPPP
#      |                                   |                   /-ABPRPPPPPAA
#      |                                   |         /ABPRPPPPPA
#      |                                   |        |          \-ABPRPPPPPAP
#      |                                    \ABPRPPPPP
#      |                                            |          /-ABPRPPPPPPA
#      |                                             \ABPRPPPPPP
#      |                                                       \-ABPRPPPPPPP
#      |
#      |                        /-EALAAD
#      |                   /EALAA
#      |               /EALA    \-EALAAV
#      |              |   |
#      |            /EAL   \-EALAP
#      |           |  |
#      |           |  |    /-EALPA
#      |           |   \EALP
#      |           |       \-EALPP
#      |         /EA
#      |        |  |            /-EARAAD
#      |        |  |       /EARAA
#      |        |  |   /EARA    \-EARAAV
#      |        |  |  |   |
#      |        |   \EAR   \-EARAP
#      |        |     |
#      |        |     |    /-EARPA
#      |        |      \EARP
#      |      /E|          \-EARPP
#      |     |  |
#      |     |  |          /-EPLAA
#      |     |  |      /EPLA
#      |     |  |     |    \-EPLAP
#      |     |  |   /EPL
#      |     |  |  |  |    /-EPLPA
#      |     |  |  |   \EPLP
#      |     |  |  |      |     /-EPLPPA
#      |     |  |  |       \EPLPP
#      |     |   \EP            \-EPLPPP
#      |     |     |
#      |     |     |       /-EPRAA
#      |     |     |   /EPRA
#      |     |     |  |    \-EPRAP
#      |     |      \EPR
#      |     |        |    /-EPRPA
#      |     |         \EPRP
#      |     |            |     /-EPRPPA
#      |     |             \EPRPP
#      |     |                  \-EPRPPP
#      |     |
#      |     |                                    /-MSAAAAAAL
#      |     |                            /MSAAAAAA
#      |     |                           |        \-MSAAAAAAR
#      |     |                     /MSAAAAA
#      |     |                    |      |                 /-MSAAAAAPAA
#      |     |                    |      |        /MSAAAAAPA
#      |     |                    |       \MSAAAAAP        \-MSAAAAAPAP
#      |     |                    |              |
#      |     |               /MSAAAA              \-MSAAAAAPP
#      |     |              |     |
#      |     |              |     |               /-MSAAAAPAA
#      |     |              |     |       /MSAAAAPA
#      |     |              |     |      |        \-MSAAAAPAP
#      |     |              |      \MSAAAAP
#      |     |              |            |        /-MSAAAAPPA
#      |     |              |             \MSAAAAPP
#      |     |          /MSAAA                    \-MSAAAAPPP
#      |     |         |    |
#      |     |         |    |                     /-MSAAAPAAA
#      |     |         |    |             /MSAAAPAA
#      |     |         |    |            |        \-MSAAAPAAP
#      |     |         |    |      /MSAAAPA
#      |     |         |    |     |      |        /-MSAAAPAPA
#      |     |         |    |     |       \MSAAAPAP
#      |     |         |     \MSAAAP              \-MSAAAPAPP
#      |     |         |          |
#      |     |         |          |       /-MSAAAPPA
#      |     |         |           \MSAAAPP
#      |     |         |                  \-MSAAAPPP
#      |     |         |
#      |     |      /MSAA                         /-MSAAPAAAA
#      |     |     |   |                  /MSAAPAAA
#      |     |     |   |                 |        \-MSAAPAAAP
#      |     |     |   |           /MSAAPAA
#      |     |     |   |          |      |                 /-MSAAPAAPAA
#      |     |     |   |          |      |        /MSAAPAAPA
#      |     |     |   |          |       \MSAAPAAP        \-MSAAPAAPAP
#      |     |     |   |          |              |
#      |   /EMS    |   |     /MSAAPA              \-MSAAPAAPP
#      |  |  |     |   |    |     |
#      |  |  |     |   |    |     |               /-MSAAPAPAA
#      |  |  |     |   |    |     |       /MSAAPAPA
#      |  |  |     |   |    |     |      |        \-MSAAPAPAP
#      |  |  |     |   |    |      \MSAAPAP
#      |  |  |     |   |    |            |        /-MSAAPAPPA
#      |  |  |     |    \MSAAP            \MSAAPAPP
#      |  |  |     |        |                     \-MSAAPAPPP
#      |  |  |     |        |
#      |  |  |     |        |             /-MSAAPPAA
#      |  |  |     |        |      /MSAAPPA
#      |  |  |     |        |     |       \-MSAAPPAP
#      |  |  |     |        |     |
#      |  |  |     |         \MSAAPP              /-MSAAPPPAA
#      |  |  |   /MSA             |       /MSAAPPPA
#      |  |  |  |  |              |      |        \-MSAAPPPAP
#      |  |  |  |  |               \MSAAPPP
#      |  |  |  |  |                     |        /-MSAAPPPPA
#      |  |  |  |  |                      \MSAAPPPP
#      |  |  |  |  |                              \-MSAAPPPPP
#      |  |  |  |  |
#      |  |  |  |  |                              /-MSAPAAAAD
#      |  |  |  |  |                      /MSAPAAAA
#      |  |  |  |  |               /MSAPAAA       \-MSAPAAAAV
#      |  |  |  |  |              |      |
#      |  |  |  |  |         /MSAPAA      \-MSAPAAAP
#      |  |  |  |  |        |     |
#      |  |  |  |  |        |      \-MSAPAAP
#      |  |  |  |  |        |
#      |  |  |  |  |    /MSAPA                    /-MSAPAPAAA
#      |  |  |  |  |   |    |             /MSAPAPAA
#      |  |  |  |  |   |    |      /MSAPAPA       \-MSAPAPAAP
#      |  |  |  |  |   |    |     |      |
#      |  |  |  |  |   |     \MSAPAP      \-MSAPAPAP
#      |  |  |  |  |   |          |
#      |  |  |  |  |   |          |       /-MSAPAPPA
#      |  |  |  |  |   |           \MSAPAPP
#      |  |  |  |   \MSAP                 \-MSAPAPPP
#      |  |  |  |      |
#      |  |  |  |      |                  /-MSAPPAAA
#      |  |  |  |      |           /MSAPPAA
#      |  |  |  |      |          |       \-MSAPPAAP
#      |  |  |  |      |     /MSAPPA
#      |  |  |  |      |    |     |       /-MSAPPAPA
#      |  |  |  |      |    |      \MSAPPAP
#      |  |  |  |      |    |             \-MSAPPAPP
#      |  |  |  |       \MSAPP
#      |  |  |  |           |             /-MSAPPPAA
#      |  |  |  |           |      /MSAPPPA
#      |  |  |  |           |     |       \-MSAPPPAP
#      |  |  |  |            \MSAPPP
#      |  |  |  |                 |       /-MSAPPPPA
#      |  |  |  |                  \MSAPPPP
#      |  |  |  |                         \-MSAPPPPP
#      |  |  |  |
#      |  |  |  |                                 /-MSPAAAAAA
#      |  |  |  |                         /MSPAAAAA
#      |  |  |  |                        |        \-MSPAAAAAP
#      |  |  |  |                  /MSPAAAA
#      |  |   \MS                 |      |        /-MSPAAAAPA
#      |  |     |                 |       \MSPAAAAP
#      |  |     |                 |               \-MSPAAAAPP
#      |  |     |            /MSPAAA
#      |  |     |           |     |               /-MSPAAAPAA
#      |  |     |           |     |       /MSPAAAPA
#      |  |     |           |     |      |        \-MSPAAAPAP
#      |  |     |           |      \MSPAAAP
#      |  |     |           |            |        /-MSPAAAPPA
#      |  |     |           |             \MSPAAAPP
#      |  |     |       /MSPAA                    \-MSPAAAPPP
#      |  |     |      |    |
#      |  |     |      |    |                     /-MSPAAPAAA
#      |  |     |      |    |             /MSPAAPAA
#      |  |     |      |    |            |        \-MSPAAPAAP
#      |  |     |      |    |      /MSPAAPA
#      |  |     |      |    |     |      |        /-MSPAAPAPA
#      |  |     |      |     \MSPAAP      \MSPAAPAP
#      |  |     |      |          |               \-MSPAAPAPP
#      |  |     |      |          |
#      |  |     |      |           \-MSPAAPP
#      |  |     |      |
#      |  |     |      |                          /-MSPAPAAAA
#      |  |     |   /MSPA                 /MSPAPAAA
#      |  |     |  |   |                 |        \-MSPAPAAAP
#      |  |     |  |   |           /MSPAPAA
#      |  |     |  |   |          |      |                 /-MSPAPAAPAA
#      |  |     |  |   |          |      |        /MSPAPAAPA
#      |  |     |  |   |          |       \MSPAPAAP        \-MSPAPAAPAP
#      |  |     |  |   |          |              |
#      |  |     |  |   |     /MSPAPA              \-MSPAPAAPP
#      |  |     |  |   |    |     |
#      |  |     |  |   |    |     |               /-MSPAPAPAA
#      |  |     |  |   |    |     |       /MSPAPAPA
#      |  |     |  |   |    |     |      |        \-MSPAPAPAP
#      |  |     |  |   |    |      \MSPAPAP
#      |  |     |  |   |    |            |        /-MSPAPAPPA
#      |  |     |  |    \MSPAP            \MSPAPAPP
#      |  |     |  |        |                     \-MSPAPAPPP
#      |  |     |  |        |
#      |  |     |  |        |             /-MSPAPPAA
#      |  |     |  |        |      /MSPAPPA
#      |  |     |  |        |     |       \-MSPAPPAP
#      |  |     |  |        |     |
#      |  |     |  |         \MSPAPP              /-MSPAPPPAA
#      |  |     |  |              |       /MSPAPPPA
#      |  |      \MSP             |      |        \-MSPAPPPAP
#      |  |        |               \MSPAPPP
#      |  |        |                     |        /-MSPAPPPPA
#      |  |        |                      \MSPAPPPP
#      |  |        |                              \-MSPAPPPPP
#      |  |        |
#      |  |        |                              /-MSPPAAAAD
#      |  |        |                      /MSPPAAAA
#      |  |        |               /MSPPAAA       \-MSPPAAAAV
#      |  |        |              |      |
#       \P1        |         /MSPPAA      \-MSPPAAAP
#         |        |        |     |
#         |        |        |     |       /-MSPPAAPA
#         |        |        |      \MSPPAAP
#         |        |        |             \-MSPPAAPP
#         |        |    /MSPPA
#         |        |   |    |                     /-MSPPAPAAA
#         |        |   |    |             /MSPPAPAA
#         |        |   |    |      /MSPPAPA       \-MSPPAPAAP
#         |        |   |    |     |      |
#         |        |   |     \MSPPAP      \-MSPPAPAP
#         |        |   |          |
#         |        |   |          |       /-MSPPAPPA
#         |        |   |           \MSPPAPP
#         |         \MSPP                 \-MSPPAPPP
#         |            |
#         |            |                  /-MSPPPAAA
#         |            |           /MSPPPAA
#         |            |          |       \-MSPPPAAP
#         |            |     /MSPPPA
#         |            |    |     |       /-MSPPPAPA
#         |            |    |      \MSPPPAP
#         |            |    |             \-MSPPPAPP
#         |             \MSPPP
#         |                 |             /-MSPPPPAA
#         |                 |      /MSPPPPA
#         |                 |     |       \-MSPPPPAP
#         |                  \MSPPPP
#         |                       |       /-MSPPPPPA
#         |                        \MSPPPPP
#         |                               \-MSPPPPPP
#         |
#         |                     /-CAAAAA
#         |                /CAAAA
#         |               |     \-CAAAAP
#         |            /CAAA
#         |           |   |     /-CAAAPA
#         |           |    \CAAAP
#         |           |         \-CAAAPP
#         |         /CAA
#         |        |  |         /-CAAPAA
#         |        |  |    /CAAPA
#         |        |  |   |     \-CAAPAP
#         |        |   \CAAP
#         |        |      |     /-CAAPPD
#         |        |       \CAAPP
#         |        |            \-CAAPPV
#         |        |
#         |        |                  /-CAPAAAA
#         |        |            /CAPAAA
#         |        |           |      \-CAPAAAP
#         |      /CA       /CAPAA
#         |     |  |      |    |      /-CAPAAPA
#         |     |  |      |     \CAPAAP
#         |     |  |      |           \-CAPAAPP
#         |     |  |   /CAPA
#         |     |  |  |   |           /-CAPAPAA
#         |     |  |  |   |     /CAPAPA
#         |     |  |  |   |    |      \-CAPAPAP
#         |     |  |  |    \CAPAP
#         |     |  |  |        |      /-CAPAPPA
#         |     |  |  |         \CAPAPP
#         |     |  |  |               \-CAPAPPP
#         |     |   \CAP
#         |     |     |               /-CAPPAAA
#         |     |     |         /CAPPAA
#         |     |     |        |      \-CAPPAAP
#         |     |     |    /CAPPA
#         |     |     |   |    |      /-CAPPAPA
#         |     |     |   |     \CAPPAP
#         |     |     |   |           \-CAPPAPP
#         |     |      \CAPP
#         |     |         |           /-CAPPPAA
#         |     |         |     /CAPPPA
#         |     |         |    |      \-CAPPPAP
#         |   /C|          \CAPPP
#         |  |  |              |      /-CAPPPPD
#         |  |  |               \CAPPPP
#         |  |  |                     \-CAPPPPV
#         |  |  |
#         |  |  |               /-CPAAAA
#         |  |  |          /CPAAA
#         |  |  |         |     \-CPAAAP
#         |  |  |      /CPAA
#         |  |  |     |   |     /-CPAAPA
#         |  |  |     |    \CPAAP
#         |  |  |     |         \-CPAAPP
#         |  |  |   /CPA
#         |  |  |  |  |         /-CPAPAA
#         |  |  |  |  |    /CPAPA
#         |  |  |  |  |   |     \-CPAPAP
#         |  |  |  |   \CPAP
#         |  |  |  |      |     /-CPAPPD
#         |  |  |  |       \CPAPP
#         |  |  |  |            \-CPAPPV
#         |  |  |  |
#         |  |  |  |                  /-CPPAAAA
#         |  |  |  |            /CPPAAA
#         |  |  |  |           |      \-CPPAAAP
#         |  |   \CP       /CPPAA
#         |  |     |      |    |      /-CPPAAPA
#         |  |     |      |     \CPPAAP
#         |  |     |      |           \-CPPAAPP
#         |  |     |   /CPPA
#         |  |     |  |   |           /-CPPAPAA
#         |  |     |  |   |     /CPPAPA
#         |  |     |  |   |    |      \-CPPAPAP
#         |  |     |  |    \CPPAP
#         |  |     |  |        |      /-CPPAPPA
#         |  |     |  |         \CPPAPP
#         |  |     |  |               \-CPPAPPP
#         |  |      \CPP
#         |  |        |               /-CPPPAAA
#         |  |        |         /CPPPAA
#         |  |        |        |      \-CPPPAAP
#         |  |        |    /CPPPA
#          \P2        |   |    |      /-CPPPAPA
#            |        |   |     \CPPPAP
#            |        |   |           \-CPPPAPP
#            |         \CPPP
#            |            |           /-CPPPPAA
#            |            |     /CPPPPA
#            |            |    |      \-CPPPPAP
#            |             \CPPPP
#            |                 |      /-CPPPPPD
#            |                  \CPPPPP
#            |                        \-CPPPPPV
#            |
#            |                /-DAAAA
#            |            /DAAA
#            |           |    \-DAAAP
#            |         /DAA
#            |        |  |    /-DAAPA
#            |        |   \DAAP
#            |        |       \-DAAPP
#            |      /DA
#            |     |  |       /-DAPAA
#            |     |  |   /DAPA
#            |     |  |  |    \-DAPAP
#            |     |  |  |
#            |     |   \DAP        /-DAPPAA
#            |     |     |    /DAPPA
#            |     |     |   |     \-DAPPAP
#            |     |      \DAPP
#            |     |         |     /-DAPPPA
#            |   /D|          \DAPPP
#            |  |  |               \-DAPPPP
#            |  |  |
#            |  |  |          /-DPAAA
#            |  |  |      /DPAA
#            |  |  |     |    \-DPAAP
#            |  |  |   /DPA
#            |  |  |  |  |    /-DPAPA
#            |  |  |  |   \DPAP
#            |  |  |  |       \-DPAPP
#            |  |   \DP
#            |  |     |       /-DPPAA
#             \P3     |   /DPPA
#               |     |  |    \-DPPAP
#               |     |  |
#               |      \DPP        /-DPPPAA
#               |        |    /DPPPA
#               |        |   |     \-DPPPAP
#               |         \DPPP
#               |            |     /-DPPPPA
#               |             \DPPPP
#               |                  \-DPPPPP
#               |
#               |   /-P4A
#                \P4
#                   \-P4P

# %%
cell_meta = pd.read_csv('/home/hschlueter/data/GSE126954/GSE126954_cell_annotation.csv')
cell_meta
# Out:
#                      Unnamed: 0                      cell  n.umi   time.point  \
# 0      AAACCTGAGACAATAC-300.1.1  AAACCTGAGACAATAC-300.1.1   1630  300_minutes
# 1      AAACCTGAGGGCTCTC-300.1.1  AAACCTGAGGGCTCTC-300.1.1   2319  300_minutes
# 2      AAACCTGAGTGCGTGA-300.1.1  AAACCTGAGTGCGTGA-300.1.1   3719  300_minutes
# 3      AAACCTGAGTTGAGTA-300.1.1  AAACCTGAGTTGAGTA-300.1.1   4251  300_minutes
# 4      AAACCTGCAAGACGTG-300.1.1  AAACCTGCAAGACGTG-300.1.1   1003  300_minutes
# ...                         ...                       ...    ...          ...
# 89696      TCTGAGACATGTCGAT-b02      TCTGAGACATGTCGAT-b02    585        mixed
# 89697      TCTGAGACATGTCTCC-b02      TCTGAGACATGTCTCC-b02    510        mixed
# 89698      TGGCCAGCACGAAGCA-b02      TGGCCAGCACGAAGCA-b02    843        mixed
# 89699      TGGCGCACAGGCAGTA-b02      TGGCGCACAGGCAGTA-b02    636        mixed
# 89700      TGGGCGTTCAGGCCCA-b02      TGGGCGTTCAGGCCCA-b02   1132        mixed
#
#                        batch  Size_Factor               cell.type  \
# 0      Waterston_300_minutes     1.023195        Body_wall_muscle
# 1      Waterston_300_minutes     1.458210                     NaN
# 2      Waterston_300_minutes     2.338283                     NaN
# 3      Waterston_300_minutes     2.659051        Body_wall_muscle
# 4      Waterston_300_minutes     0.629610  Ciliated_amphid_neuron
# ...                      ...          ...                     ...
# 89696             Murray_b02     0.364709            Rectal_gland
# 89697             Murray_b02     0.323907                     NaN
# 89698             Murray_b02     0.529174                     NaN
# 89699             Murray_b02     0.397979                     NaN
# 89700             Murray_b02     0.706820                     NaN
#
#          cell.subtype  plot.cell.type  raw.embryo.time  embryo.time  \
# 0      BWM_head_row_1  BWM_head_row_1              360        380.0
# 1                 NaN             NaN              260        220.0
# 2                 NaN             NaN              270        230.0
# 3        BWM_anterior    BWM_anterior              260        280.0
# 4                 AFD             AFD              350        350.0
# ...               ...             ...              ...          ...
# 89696    Rectal_gland    Rectal_gland              390        700.0
# 89697             NaN             NaN              510        470.0
# 89698             NaN             NaN              400        470.0
# 89699             NaN             NaN              330        350.0
# 89700             NaN             NaN              260        265.0
#
#       embryo.time.bin raw.embryo.time.bin                  lineage  \
# 0             330-390             330-390                 MSxpappp
# 1             210-270             210-270                 MSxapaap
# 2             210-270             270-330                      NaN
# 3             270-330             210-270                     Dxap
# 4             330-390             330-390  ABalpppapav/ABpraaaapav
# ...               ...                 ...                      ...
# 89696           > 650             390-450                      NaN
# 89697         450-510             510-580                      NaN
# 89698         450-510             390-450                      NaN
# 89699         330-390             330-390                      NaN
# 89700         210-270             210-270                      NaN
#
#        passed_initial_QC_or_later_whitelisted
# 0                                        True
# 1                                        True
# 2                                        True
# 3                                        True
# 4                                        True
# ...                                       ...
# 89696                                    True
# 89697                                    True
# 89698                                    True
# 89699                                    True
# 89700                                    True
#
# [89701 rows x 15 columns]

# %%
print(len(cell_meta))
pruned_meta = cell_meta[~cell_meta['lineage'].isna()]
print(len(pruned_meta))
pruned_meta = pruned_meta[pruned_meta['passed_initial_QC_or_later_whitelisted']]
print(len(pruned_meta))
pruned_meta
# Out:
# 89701
# 47798
# 47798
#                      Unnamed: 0                      cell  n.umi   time.point  \
# 0      AAACCTGAGACAATAC-300.1.1  AAACCTGAGACAATAC-300.1.1   1630  300_minutes
# 1      AAACCTGAGGGCTCTC-300.1.1  AAACCTGAGGGCTCTC-300.1.1   2319  300_minutes
# 3      AAACCTGAGTTGAGTA-300.1.1  AAACCTGAGTTGAGTA-300.1.1   4251  300_minutes
# 4      AAACCTGCAAGACGTG-300.1.1  AAACCTGCAAGACGTG-300.1.1   1003  300_minutes
# 5      AAACCTGCAAGGTTCT-300.1.1  AAACCTGCAAGGTTCT-300.1.1   1319  300_minutes
# ...                         ...                       ...    ...          ...
# 89659      AGGTCATCAGCCAGAA-b02      AGGTCATCAGCCAGAA-b02    526        mixed
# 89681      GACTGCGCACTTAAGC-b02      GACTGCGCACTTAAGC-b02    761        mixed
# 89682      GCAAACTCACCTATCC-b02      GCAAACTCACCTATCC-b02    642        mixed
# 89690      GTAGGCCTCTACTATC-b02      GTAGGCCTCTACTATC-b02    568        mixed
# 89692      GTGAAGGGTTGAGTTC-b02      GTGAAGGGTTGAGTTC-b02    642        mixed
#
#                        batch  Size_Factor               cell.type  \
# 0      Waterston_300_minutes     1.023195        Body_wall_muscle
# 1      Waterston_300_minutes     1.458210                     NaN
# 3      Waterston_300_minutes     2.659051        Body_wall_muscle
# 4      Waterston_300_minutes     0.629610  Ciliated_amphid_neuron
# 5      Waterston_300_minutes     0.835505       Pharyngeal_neuron
# ...                      ...          ...                     ...
# 89659             Murray_b02     0.330184            Rectal_gland
# 89681             Murray_b02     0.475189            Rectal_gland
# 89682             Murray_b02     0.403001            Rectal_gland
# 89690             Murray_b02     0.356549             Rectal_cell
# 89692             Murray_b02     0.403001             Rectal_cell
#
#          cell.subtype  plot.cell.type  raw.embryo.time  embryo.time  \
# 0      BWM_head_row_1  BWM_head_row_1              360        380.0
# 1                 NaN             NaN              260        220.0
# 3        BWM_anterior    BWM_anterior              260        280.0
# 4                 AFD             AFD              350        350.0
# 5      I2_grandparent  I2_grandparent              260        270.0
# ...               ...             ...              ...          ...
# 89659          rect_D          rect_D              380        355.0
# 89681    Rectal_gland    Rectal_gland              410        450.0
# 89682    Rectal_gland    Rectal_gland              350        405.0
# 89690             F_U             F_U              320        320.0
# 89692               Y               Y              320        365.0
#
#       embryo.time.bin raw.embryo.time.bin                  lineage  \
# 0             330-390             330-390                 MSxpappp
# 1             210-270             210-270                 MSxapaap
# 3             270-330             210-270                     Dxap
# 4             330-390             330-390  ABalpppapav/ABpraaaapav
# 5             270-330             210-270    ABalpappaa/ABarapapaa
# ...               ...                 ...                      ...
# 89659         330-390             330-390              ABplpappppp
# 89681         450-510             390-450  ABplpappppp/ABpxppppaap
# 89682         390-450             330-390  ABplpappppp/ABpxppppaap
# 89690         270-330             270-330              ABplppppapx
# 89692         330-390             270-330              ABprpppaaaa
#
#        passed_initial_QC_or_later_whitelisted
# 0                                        True
# 1                                        True
# 3                                        True
# 4                                        True
# 5                                        True
# ...                                       ...
# 89659                                    True
# 89681                                    True
# 89682                                    True
# 89690                                    True
# 89692                                    True
#
# [47798 rows x 15 columns]

# %% [markdown]
# ### Expand and deduplicate lineages

# %%
meta_lineages = pruned_meta['lineage'].str.split('/', expand=True)
meta_lineages.index = pruned_meta.index
meta_lineages
# Out:
#                  0            1     2     3     4     5
# 0         MSxpappp         None  None  None  None  None
# 1         MSxapaap         None  None  None  None  None
# 3             Dxap         None  None  None  None  None
# 4      ABalpppapav  ABpraaaapav  None  None  None  None
# 5       ABalpappaa   ABarapapaa  None  None  None  None
# ...            ...          ...   ...   ...   ...   ...
# 89659  ABplpappppp         None  None  None  None  None
# 89681  ABplpappppp  ABpxppppaap  None  None  None  None
# 89682  ABplpappppp  ABpxppppaap  None  None  None  None
# 89690  ABplppppapx         None  None  None  None  None
# 89692  ABprpppaaaa         None  None  None  None  None
#
# [47798 rows x 6 columns]

# %%
lineage_patterns = meta_lineages.values.flatten()
lineage_patterns = lineage_patterns[~(lineage_patterns == None)]
lineage_patterns = np.unique(lineage_patterns)
print(len(lineage_patterns))
lineage_patterns
# Out:
# 665
# array(['28_cell_or_earlier', 'ABalaaaa', 'ABalaaaal', 'ABalaaaala',
#        'ABalaaaalal', 'ABalaaaalp', 'ABalaaaar', 'ABalaaaarx',
#        'ABalaaaarxp', 'ABalaaap', 'ABalaaapal', 'ABalaaapall',
#        'ABalaaapalr', 'ABalaaapar', 'ABalaaappl', 'ABalaaappr',
#        'ABalaaapprl', 'ABalaaapprr', 'ABalaaapx', 'ABalaapa', 'ABalaapaa',
#        'ABalaapaaa', 'ABalaapaaar', 'ABalaapaap', 'ABalaapap',
#        'ABalaapapp', 'ABalaapappp', 'ABalaapp', 'ABalaappa', 'ABalaappap',
#        'ABalaappapa', 'ABalaappp', 'ABalaapppa', 'ABalaapppaa',
#        'ABalaapppp', 'ABalaappppa', 'ABalaappppaa', 'ABalaappppp',
#        'ABalaax', 'ABalapaa', 'ABalapaaa', 'ABalapaaaa', 'ABalapaaaaa',
#        'ABalapaaap', 'ABalapaaapa', 'ABalapaap', 'ABalapaapa',
#        'ABalapaapaa', 'ABalapaapp', 'ABalapaappa', 'ABalapaappaa',
#        'ABalapaappp', 'ABalapapa', 'ABalappa', 'ABalappaa', 'ABalappaap',
#        'ABalappaapa', 'ABalappap', 'ABalappapa', 'ABalappapaa',
#        'ABalappapp', 'ABalappappa', 'ABalapppa', 'ABalapppaa',
#        'ABalapppaaa', 'ABalapppaap', 'ABalapx', 'ABalapxa', 'ABalapxp',
#        'ABalapxpa', 'ABalapxpap', 'ABalapxpapa', 'ABalapxpapaa',
#        'ABalapxpp', 'ABalapxppa', 'ABalapxppaa', 'ABalapxppaaa',
#        'ABalapxppap', 'ABalapxppp', 'ABalapxpppa', 'ABalapxpppp',
#        'ABalpaaa', 'ABalpaaaa', 'ABalpaaaaa', 'ABalpaaaap', 'ABalpaaap',
#        'ABalpaaapa', 'ABalpaaapp', 'ABalpaap', 'ABalpaapa', 'ABalpaapaa',
#        'ABalpaapaaa', 'ABalpaapap', 'ABalpaapapa', 'ABalpaapp',
#        'ABalpaappa', 'ABalpaappaa', 'ABalpaappap', 'ABalpaappp',
#        'ABalpaapppx', 'ABalpapa', 'ABalpapaa', 'ABalpapaaa',
#        'ABalpapaaap', 'ABalpapaap', 'ABalpapaapa', 'ABalpapap',
#        'ABalpapapa', 'ABalpapapaa', 'ABalpapapapp', 'ABalpapapp',
#        'ABalpapappp', 'ABalpapp', 'ABalpappa', 'ABalpappaa', 'ABalpappap',
#        'ABalpappapp', 'ABalpappp', 'ABalpapppa', 'ABalpapppp',
#        'ABalpappppa', 'ABalpax', 'ABalppa', 'ABalppaa', 'ABalppaaa',
#        'ABalppaaap', 'ABalppaaapa', 'ABalppaap', 'ABalppaapp',
#        'ABalppaappp', 'ABalppap', 'ABalppapa', 'ABalppapaa',
#        'ABalppapaaa', 'ABalppapap', 'ABalppapapp', 'ABalppapp',
#        'ABalppappa', 'ABalppappaa', 'ABalppappap', 'ABalppappp',
#        'ABalppapppa', 'ABalppapppaa', 'ABalppapppp', 'ABalppp',
#        'ABalpppa', 'ABalpppaa', 'ABalpppaaa', 'ABalpppaaaa', 'ABalpppaap',
#        'ABalpppap', 'ABalpppapa', 'ABalpppapad', 'ABalpppapav',
#        'ABalpppapp', 'ABalpppappp', 'ABalpppapppa', 'ABalpppp',
#        'ABalppppa', 'ABalppppaa', 'ABalppppaad', 'ABalppppap',
#        'ABalppppapa', 'ABalppppapaa', 'ABalppppp', 'ABalpppppa',
#        'ABalpppppaa', 'ABalpppppap', 'ABalpppppp', 'ABalppppppa',
#        'ABalppppppaa', 'ABalppppppp', 'ABalpppppppa', 'ABalpppppppp',
#        'ABaraaaa', 'ABaraaaaa', 'ABaraaaaax', 'ABaraaaap', 'ABaraaaapa',
#        'ABaraaap', 'ABaraaapa', 'ABaraaapaa', 'ABaraaapaaa', 'ABaraaapap',
#        'ABaraaapapa', 'ABaraaapp', 'ABaraaappa', 'ABaraaappax',
#        'ABaraaappp', 'ABaraaapppa', 'ABaraaapppp', 'ABaraapaaa',
#        'ABaraappaa', 'ABaraapx', 'ABaraapxa', 'ABaraapxap', 'ABaraapxapp',
#        'ABaraapxp', 'ABaraapxpa', 'ABaraapxpaa', 'ABaraapxpp', 'ABaraax',
#        'ABarapa', 'ABarapaa', 'ABarapaaa', 'ABarapaaaa', 'ABarapaaap',
#        'ABarapaap', 'ABarapaapa', 'ABarapaapp', 'ABarapap', 'ABarapapa',
#        'ABarapapaa', 'ABarapapap', 'ABarapapapa', 'ABarapapapp',
#        'ABarapapp', 'ABarapappa', 'ABarapappp', 'ABarapapppa', 'ABarappa',
#        'ABarappaa', 'ABarappaaa', 'ABarappaap', 'ABarappaapa',
#        'ABarappap', 'ABarappapa', 'ABarappapaa', 'ABarappapapp',
#        'ABarappapp', 'ABarappappp', 'ABarappp', 'ABarapppa', 'ABarapppaa',
#        'ABarapppaaa', 'ABarapppap', 'ABarapppapp', 'ABarapppp',
#        'ABarappppa', 'ABarappppaa', 'ABarappppap', 'ABarappppp',
#        'ABarapppppa', 'ABarapppppaa', 'ABarapppppp', 'ABarpaa',
#        'ABarpaaa', 'ABarpaaaa', 'ABarpaaaaa', 'ABarpaaaap', 'ABarpaaaapp',
#        'ABarpaaap', 'ABarpaaapa', 'ABarpaaapap', 'ABarpaap', 'ABarpaapaa',
#        'ABarpaapap', 'ABarpaappx', 'ABarpaapx', 'ABarpaapxx', 'ABarpap',
#        'ABarpapa', 'ABarpapaa', 'ABarpapaaa', 'ABarpapaap', 'ABarpapaapp',
#        'ABarpapaappa', 'ABarpapaappp', 'ABarpapap', 'ABarpapapx',
#        'ABarpapp', 'ABarpappa', 'ABarpappaa', 'ABarpappap', 'ABarpappp',
#        'ABarpapppx', 'ABarppx', 'ABarppxa', 'ABarppxaa', 'ABarppxaaa',
#        'ABarppxaap', 'ABarppxap', 'ABarppxapa', 'ABarppxapp',
#        'ABarppxappx', 'ABarppxp', 'ABarppxpa', 'ABarppxpax', 'ABarppxpp',
#        'ABarppxppa', 'ABarppxppp', 'ABarpx', 'ABaxx', 'ABplaaa',
#        'ABplaaaa', 'ABplaaaaa', 'ABplaaaaaa', 'ABplaaaaap', 'ABplaaaaapp',
#        'ABplaaaaappa', 'ABplaaaaappp', 'ABplaaaap', 'ABplaaaapx',
#        'ABplaaap', 'ABplaaapa', 'ABplaaapaa', 'ABplaaapap', 'ABplaaapp',
#        'ABplaaappx', 'ABplpapp', 'ABplpappa', 'ABplpappaa', 'ABplpappaaa',
#        'ABplpappaap', 'ABplpappp', 'ABplpapppa', 'ABplpapppax',
#        'ABplpapppp', 'ABplpappppa', 'ABplpappppp', 'ABplppppapx',
#        'ABpraaa', 'ABpraaaa', 'ABpraaaaa', 'ABpraaaaaa', 'ABpraaaaaaa',
#        'ABpraaaaap', 'ABpraaaap', 'ABpraaaapa', 'ABpraaaapad',
#        'ABpraaaapav', 'ABpraaaapp', 'ABpraaaappp', 'ABpraaaapppa',
#        'ABpraaap', 'ABpraaapa', 'ABpraaapaa', 'ABpraaapaad', 'ABpraaapap',
#        'ABpraaapapa', 'ABpraaapapaa', 'ABpraaapp', 'ABpraaappa',
#        'ABpraaappaa', 'ABpraaappap', 'ABpraaappp', 'ABpraaapppa',
#        'ABpraaapppaa', 'ABpraaapppp', 'ABpraaappppa', 'ABpraaappppp',
#        'ABprpapp', 'ABprpappa', 'ABprpappaa', 'ABprpappaaa',
#        'ABprpappaap', 'ABprpappap', 'ABprpappapa', 'ABprpappp',
#        'ABprpapppa', 'ABprpapppap', 'ABprpapppp', 'ABprpppaaaa',
#        'ABprppppapa', 'ABprppppapp', 'ABpxaap', 'ABpxaapa', 'ABpxaapaa',
#        'ABpxaapaaa', 'ABpxaapaaaa', 'ABpxaapaaap', 'ABpxaapaap',
#        'ABpxaapaapa', 'ABpxaapaapp', 'ABpxaapap', 'ABpxaapapa',
#        'ABpxaapapaa', 'ABpxaapapap', 'ABpxaapapp', 'ABpxaapappa',
#        'ABpxaapappp', 'ABpxaapapppa', 'ABpxaapp', 'ABpxaappa',
#        'ABpxaappaa', 'ABpxaappap', 'ABpxaappp', 'ABpxaapppa',
#        'ABpxaapppp', 'ABpxapa', 'ABpxapaa', 'ABpxapaaa', 'ABpxapaaaa',
#        'ABpxapaaaap', 'ABpxapaaaapa', 'ABpxapaaap', 'ABpxapaaapa',
#        'ABpxapaaapad', 'ABpxapaaapav', 'ABpxapaap', 'ABpxapaapa',
#        'ABpxapaapp', 'ABpxapap', 'ABpxapapa', 'ABpxapapaa', 'ABpxapapap',
#        'ABpxapapp', 'ABpxapappa', 'ABpxapappp', 'ABpxapapppp', 'ABpxapp',
#        'ABpxappa', 'ABpxappaa', 'ABpxappaaa', 'ABpxappaap', 'ABpxappap',
#        'ABpxappapa', 'ABpxappapp', 'ABpxappp', 'ABpxapppa', 'ABpxapppaa',
#        'ABpxapppaaa', 'ABpxapppap', 'ABpxapppapp', 'ABpxapppappp',
#        'ABpxapppp', 'ABpxappppa', 'ABpxappppp', 'ABpxax', 'ABpxp',
#        'ABpxpa', 'ABpxpaa', 'ABpxpaaa', 'ABpxpaaaa', 'ABpxpaaaaa',
#        'ABpxpaaaaap', 'ABpxpaaaap', 'ABpxpaaaapa', 'ABpxpaaap',
#        'ABpxpaaapa', 'ABpxpaaapap', 'ABpxpaaapp', 'ABpxpaaappa',
#        'ABpxpaaappaa', 'ABpxpaap', 'ABpxpaapa', 'ABpxpaapaa',
#        'ABpxpaapaaa', 'ABpxpaapaap', 'ABpxpaapap', 'ABpxpaapapa',
#        'ABpxpaapp', 'ABpxpaappa', 'ABpxpaappaa', 'ABpxpaappap',
#        'ABpxpaappp', 'ABpxpaapppa', 'ABpxpaappppa', 'ABpxpap', 'ABpxpapa',
#        'ABpxpapaa', 'ABpxpapaaa', 'ABpxpapaaaa', 'ABpxpapaaap',
#        'ABpxpapaap', 'ABpxpapaapa', 'ABpxpapaapp', 'ABpxpapap',
#        'ABpxpapapa', 'ABpxpapapaa', 'ABpxpapapap', 'ABpxpapapp',
#        'ABpxpapappa', 'ABpxpp', 'ABpxppa', 'ABpxppaa', 'ABpxppaaa',
#        'ABpxppaaaa', 'ABpxppaaaaa', 'ABpxppaaaap', 'ABpxppaaaapp',
#        'ABpxppaap', 'ABpxppaapa', 'ABpxppaapap', 'ABpxppaapp', 'ABpxppap',
#        'ABpxppapa', 'ABpxppapaa', 'ABpxppapap', 'ABpxppapp', 'ABpxppappa',
#        'ABpxppappp', 'ABpxppp', 'ABpxpppa', 'ABpxpppaa', 'ABpxpppaaa',
#        'ABpxpppaap', 'ABpxpppaapa', 'ABpxpppap', 'ABpxpppapa', 'ABpxpppp',
#        'ABpxppppa', 'ABpxppppaa', 'ABpxppppaaa', 'ABpxppppaap',
#        'ABpxppppap', 'ABpxppppp', 'ABpxpppppa', 'ABpxpppppp', 'Caapa',
#        'Caapaa', 'Caappv', 'Cpapa', 'Cpapax', 'Cpappv', 'Cx', 'Cxa',
#        'Cxaa', 'Cxaaax', 'Cxaapa', 'Cxaapp', 'Cxaax', 'Cxap', 'Cxapp',
#        'Cxappd', 'Cxp', 'Cxpa', 'Cxpaa', 'Cxpaaa', 'Cxpaaax', 'Cxpaap',
#        'Cxpaapx', 'Cxpap', 'Cxpapa', 'Cxpapax', 'Cxpapp', 'Cxpappx',
#        'Cxpp', 'Cxppa', 'Cxppaa', 'Cxppaax', 'Cxppap', 'Cxppapx', 'Cxppp',
#        'Cxpppa', 'Cxpppax', 'Cxpppp', 'Cxppppx', 'Dx', 'Dxa', 'Dxaap',
#        'Dxap', 'Dxapa', 'Dxapp', 'Dxapx', 'Dxp', 'Dxpap', 'Dxpp', 'Dxppa',
#        'Dxppax', 'Dxppp', 'Dxpppx', 'Dxxa', 'Dxxaa', 'Dxxax', 'Eaxaa',
#        'Eaxap', 'Eaxpa', 'Eaxpp', 'Epxaa', 'Epxap', 'Epxpa', 'Epxpp',
#        'Exx', 'Exxx', 'MSaaaaa', 'MSaaaaaa', 'MSaaaaaax', 'MSaaaaap',
#        'MSaaaaapa', 'MSaaaap', 'MSaaaapa', 'MSaaaapp', 'MSaaaappp',
#        'MSaaapaa', 'MSaaapapp', 'MSaaapp', 'MSaaappp', 'MSaappa',
#        'MSapaap', 'MSapaapp', 'MSappaaa', 'MSpaaaa', 'MSpaaaaa',
#        'MSpaaaap', 'MSpaaap', 'MSpaaapa', 'MSpaaapp', 'MSpaaappp',
#        'MSpaapaa', 'MSpappa', 'MSpappax', 'MSppaap', 'MSppaapp',
#        'MSpppaaa', 'MSx', 'MSxa', 'MSxaa', 'MSxaaa', 'MSxaap', 'MSxaapa',
#        'MSxaapap', 'MSxaapapa', 'MSxap', 'MSxapa', 'MSxapaa', 'MSxapaaa',
#        'MSxapaap', 'MSxapaapa', 'MSxapaapp', 'MSxapap', 'MSxapapa',
#        'MSxapapaa', 'MSxapapp', 'MSxapappa', 'MSxapp', 'MSxappp',
#        'MSxapppa', 'MSxapppax', 'MSxapppp', 'MSxappppx', 'MSxp', 'MSxpa',
#        'MSxpaa', 'MSxpaaa', 'MSxpaaaa', 'MSxpaaaax', 'MSxpaaap', 'MSxpap',
#        'MSxpapa', 'MSxpapaa', 'MSxpapap', 'MSxpapp', 'MSxpappa',
#        'MSxpappp', 'MSxpp', 'MSxppa', 'MSxppaa', 'MSxppaaa', 'MSxppaap',
#        'MSxppap', 'MSxppapp', 'MSxppp', 'MSxpppa', 'MSxpppaa', 'MSxpppap',
#        'MSxpppax', 'MSxpppp', 'MSxppppa', 'MSxppppp', 'MSxppppx', 'Z2',
#        'Z3:pseudotime_bin_1', 'Z3:pseudotime_bin_2',
#        'Z3:pseudotime_bin_3'], dtype=object)

# %%
from tqdm import tqdm

lineages = pd.Series(lineage_patterns)
regex_lineages = lineages.str.replace('x', '[xaplrvd]')
matches = pd.DataFrame(np.zeros((len(lineages), len(lineages))).astype(bool))
matches.columns = regex_lineages
for rexp in tqdm(regex_lineages):
  matches[rexp] = lineages.str.fullmatch(rexp)
matches.index = lineages
matches
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 665/665 [00:00<00:00, 2779.95it/s]
#                      28_cell_or_earlier  ABalaaaa  ABalaaaal  ABalaaaala  \
# 28_cell_or_earlier                 True     False      False       False
# ABalaaaa                          False      True      False       False
# ABalaaaal                         False     False       True       False
# ABalaaaala                        False     False      False        True
# ABalaaaalal                       False     False      False       False
# ...                                 ...       ...        ...         ...
# MSxppppx                          False     False      False       False
# Z2                                False     False      False       False
# Z3:pseudotime_bin_1               False     False      False       False
# Z3:pseudotime_bin_2               False     False      False       False
# Z3:pseudotime_bin_3               False     False      False       False
#
#                      ABalaaaalal  ABalaaaalp  ABalaaaar  ABalaaaar[xaplrvd]  \
# 28_cell_or_earlier         False       False      False               False
# ABalaaaa                   False       False      False               False
# ABalaaaal                  False       False      False               False
# ABalaaaala                 False       False      False               False
# ABalaaaalal                 True       False      False               False
# ...                          ...         ...        ...                 ...
# MSxppppx                   False       False      False               False
# Z2                         False       False      False               False
# Z3:pseudotime_bin_1        False       False      False               False
# Z3:pseudotime_bin_2        False       False      False               False
# Z3:pseudotime_bin_3        False       False      False               False
#
#                      ABalaaaar[xaplrvd]p  ABalaaap  ...  MS[xaplrvd]pppap  \
# 28_cell_or_earlier                 False     False  ...             False
# ABalaaaa                           False     False  ...             False
# ABalaaaal                          False     False  ...             False
# ABalaaaala                         False     False  ...             False
# ABalaaaalal                        False     False  ...             False
# ...                                  ...       ...  ...               ...
# MSxppppx                           False     False  ...             False
# Z2                                 False     False  ...             False
# Z3:pseudotime_bin_1                False     False  ...             False
# Z3:pseudotime_bin_2                False     False  ...             False
# Z3:pseudotime_bin_3                False     False  ...             False
#
#                      MS[xaplrvd]pppa[xaplrvd]  MS[xaplrvd]pppp  \
# 28_cell_or_earlier                      False            False
# ABalaaaa                                False            False
# ABalaaaal                               False            False
# ABalaaaala                              False            False
# ABalaaaalal                             False            False
# ...                                       ...              ...
# MSxppppx                                False            False
# Z2                                      False            False
# Z3:pseudotime_bin_1                     False            False
# Z3:pseudotime_bin_2                     False            False
# Z3:pseudotime_bin_3                     False            False
#
#                      MS[xaplrvd]ppppa  MS[xaplrvd]ppppp  \
# 28_cell_or_earlier              False             False
# ABalaaaa                        False             False
# ABalaaaal                       False             False
# ABalaaaala                      False             False
# ABalaaaalal                     False             False
# ...                               ...               ...
# MSxppppx                        False             False
# Z2                              False             False
# Z3:pseudotime_bin_1             False             False
# Z3:pseudotime_bin_2             False             False
# Z3:pseudotime_bin_3             False             False
#
#                      MS[xaplrvd]pppp[xaplrvd]     Z2  Z3:pseudotime_bin_1  \
# 28_cell_or_earlier                      False  False                False
# ABalaaaa                                False  False                False
# ABalaaaal                               False  False                False
# ABalaaaala                              False  False                False
# ABalaaaalal                             False  False                False
# ...                                       ...    ...                  ...
# MSxppppx                                 True  False                False
# Z2                                      False   True                False
# Z3:pseudotime_bin_1                     False  False                 True
# Z3:pseudotime_bin_2                     False  False                False
# Z3:pseudotime_bin_3                     False  False                False
#
#                      Z3:pseudotime_bin_2  Z3:pseudotime_bin_3
# 28_cell_or_earlier                 False                False
# ABalaaaa                           False                False
# ABalaaaal                          False                False
# ABalaaaala                         False                False
# ABalaaaalal                        False                False
# ...                                  ...                  ...
# MSxppppx                           False                False
# Z2                                 False                False
# Z3:pseudotime_bin_1                False                False
# Z3:pseudotime_bin_2                 True                False
# Z3:pseudotime_bin_3                False                 True
#
# [665 rows x 665 columns]

# %%
# nothing unmatched
(matches.sum(axis=1) == 0).sum()
# Out:
# 0

# %%
# for some reason there are versions of lineages subsuming other lineages
print((matches.sum(axis=1) != 1).sum())

sub = matches[matches.sum(axis=1) != 1]
for idx, row in sub.iterrows():
    print(idx, 'matches', sub.columns.values[row.values])
# Out:
# 18
# ABalapaa matches ['ABalapaa' 'ABalap[xaplrvd]a']
# ABalapapa matches ['ABalapapa' 'ABalap[xaplrvd]pa']
# ABalappa matches ['ABalappa' 'ABalap[xaplrvd]a']
# ABalapppa matches ['ABalapppa' 'ABalap[xaplrvd]pa']
# ABarpaapaa matches ['ABarpaapaa' 'ABarpaap[xaplrvd][xaplrvd]']
# ABarpaapap matches ['ABarpaapap' 'ABarpaap[xaplrvd][xaplrvd]']
# ABarpaappx matches ['ABarpaapp[xaplrvd]' 'ABarpaap[xaplrvd][xaplrvd]']
# Dxaap matches ['D[xaplrvd]aap' 'D[xaplrvd][xaplrvd]a[xaplrvd]']
# Dxapa matches ['D[xaplrvd]apa' 'D[xaplrvd]ap[xaplrvd]']
# Dxapp matches ['D[xaplrvd]app' 'D[xaplrvd]ap[xaplrvd]']
# Dxpap matches ['D[xaplrvd]pap' 'D[xaplrvd][xaplrvd]a[xaplrvd]']
# Dxxaa matches ['D[xaplrvd][xaplrvd]aa' 'D[xaplrvd][xaplrvd]a[xaplrvd]']
# MSappaaa matches ['MSappaaa' 'MS[xaplrvd]ppaaa']
# MSpppaaa matches ['MSpppaaa' 'MS[xaplrvd]ppaaa']
# MSxpppaa matches ['MS[xaplrvd]pppaa' 'MS[xaplrvd]pppa[xaplrvd]']
# MSxpppap matches ['MS[xaplrvd]pppap' 'MS[xaplrvd]pppa[xaplrvd]']
# MSxppppa matches ['MS[xaplrvd]ppppa' 'MS[xaplrvd]pppp[xaplrvd]']
# MSxppppp matches ['MS[xaplrvd]ppppp' 'MS[xaplrvd]pppp[xaplrvd]']

# %%
sorter = np.argsort(- matches.sum(axis=0))
ordered_cols = matches.columns[sorter]
ordered_matches = matches[ordered_cols].iloc[sorter]
match_counts = ordered_matches.sum(axis=0)
match_counts
# Out:
# D[xaplrvd][xaplrvd]a[xaplrvd]    4
# ABarpaap[xaplrvd][xaplrvd]       4
# ABalap[xaplrvd]a                 3
# MS[xaplrvd]pppp[xaplrvd]         3
# ABalap[xaplrvd]pa                3
#                                 ..
# ABarappaapa                      1
# ABarappap                        1
# ABarappapa                       1
# ABarappapapp                     1
# Z3:pseudotime_bin_3              1
# Length: 665, dtype: int64

# %%
multi_match = match_counts[match_counts > 1]
print(len(multi_match))
multi_match
# Out:
# 8
# D[xaplrvd][xaplrvd]a[xaplrvd]    4
# ABarpaap[xaplrvd][xaplrvd]       4
# ABalap[xaplrvd]a                 3
# MS[xaplrvd]pppp[xaplrvd]         3
# ABalap[xaplrvd]pa                3
# D[xaplrvd]ap[xaplrvd]            3
# MS[xaplrvd]pppa[xaplrvd]         3
# MS[xaplrvd]ppaaa                 3
# dtype: int64

# %%
# multi-matches are not nested, so no need for recursive replacement
ordered_matches.iloc[:8, :8].sum(axis=0)
# Out:
# D[xaplrvd][xaplrvd]a[xaplrvd]    1
# ABarpaap[xaplrvd][xaplrvd]       1
# ABalap[xaplrvd]a                 1
# MS[xaplrvd]pppp[xaplrvd]         1
# ABalap[xaplrvd]pa                1
# D[xaplrvd]ap[xaplrvd]            1
# MS[xaplrvd]pppa[xaplrvd]         1
# MS[xaplrvd]ppaaa                 1
# dtype: int64

# %%
# find rows matching just one regex (themself)
good_lineages = np.argwhere((matches.sum(axis=1) == 1).values).flatten()
# remove columns (regex) for bad lineages
unique_matches = matches.iloc[:, good_lineages]
assert (unique_matches.sum(axis=1) == 1).all()

metalineage_to_regex = {}
for lineage in unique_matches.index:
  metalineage_to_regex[lineage] = unique_matches.columns[unique_matches.loc[lineage].argmax()]

meta_regex_lineages = meta_lineages.replace(metalineage_to_regex)
meta_regex_lineages
# Out:
#                          0                    1     2     3     4     5
# 0         MS[xaplrvd]pappp                 None  None  None  None  None
# 1         MS[xaplrvd]apaap                 None  None  None  None  None
# 3             D[xaplrvd]ap                 None  None  None  None  None
# 4              ABalpppapav          ABpraaaapav  None  None  None  None
# 5               ABalpappaa           ABarapapaa  None  None  None  None
# ...                    ...                  ...   ...   ...   ...   ...
# 89659          ABplpappppp                 None  None  None  None  None
# 89681          ABplpappppp  ABp[xaplrvd]ppppaap  None  None  None  None
# 89682          ABplpappppp  ABp[xaplrvd]ppppaap  None  None  None  None
# 89690  ABplppppap[xaplrvd]                 None  None  None  None  None
# 89692          ABprpppaaaa                 None  None  None  None  None
#
# [47798 rows x 6 columns]

# %%
meta_regex_lineages_joined = meta_regex_lineages.apply(
    lambda x: '|'.join(x.dropna().astype(str)),
    axis=1
)
meta_regex_lineages_joined
# Out:
# 0                       MS[xaplrvd]pappp
# 1                       MS[xaplrvd]apaap
# 3                           D[xaplrvd]ap
# 4                ABalpppapav|ABpraaaapav
# 5                  ABalpappaa|ABarapapaa
#                       ...
# 89659                        ABplpappppp
# 89681    ABplpappppp|ABp[xaplrvd]ppppaap
# 89682    ABplpappppp|ABp[xaplrvd]ppppaap
# 89690                ABplppppap[xaplrvd]
# 89692                        ABprpppaaaa
# Length: 47798, dtype: object

# %%
meta_regex_lineages_joined_set = meta_regex_lineages_joined.unique()
meta_regex_lineages_joined_set_to_cell_ids = {}
for reg in meta_regex_lineages_joined_set:
  meta_regex_lineages_joined_set_to_cell_ids[reg] = meta_regex_lineages_joined[meta_regex_lineages_joined == reg].index.values

print(len(meta_regex_lineages_joined_set))
# Out:
# 499

# %% [markdown]
# ### Extract leaves for lineages

# %%
pruned_tree = dendropy.Tree.get(path=f'{data_path}/celegans_1.nwk', schema='newick')
# add taxa to internal nodes
for node in pruned_tree.internal_nodes():
  node.taxon = dendropy.Taxon(node.label)
leaf_labels = np.array([t.taxon.label for t in pruned_tree.leaf_nodes()])
leaf_labels = pd.Series(leaf_labels).sort_values()

# %%
leaf_matches = pd.DataFrame(np.zeros((len(leaf_labels), len(meta_regex_lineages_joined_set))).astype(bool))
leaf_matches.columns = meta_regex_lineages_joined_set
leaf_matches.index = leaf_labels
for rexp in tqdm(meta_regex_lineages_joined_set):
  leaf_matches[rexp] = leaf_labels.str.fullmatch(str.upper(rexp)).values
leaf_matches
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 499/499 [00:00<00:00, 2798.85it/s]
#              MS[xaplrvd]pappp  MS[xaplrvd]apaap  D[xaplrvd]ap  \
# ABALAAAALAL             False             False         False
# ABALAAAALAR             False             False         False
# ABALAAAALPA             False             False         False
# ABALAAAALPP             False             False         False
# ABALAAAARLA             False             False         False
# ...                       ...               ...           ...
# MSPPPPAP                False             False         False
# MSPPPPPA                False             False         False
# MSPPPPPP                False             False         False
# P4A                     False             False         False
# P4P                     False             False         False
#
#              ABalpppapav|ABpraaaapav  ABalpappaa|ABarapapaa  \
# ABALAAAALAL                    False                  False
# ABALAAAALAR                    False                  False
# ABALAAAALPA                    False                  False
# ABALAAAALPP                    False                  False
# ABALAAAARLA                    False                  False
# ...                              ...                    ...
# MSPPPPAP                       False                  False
# MSPPPPPA                       False                  False
# MSPPPPPP                       False                  False
# P4A                            False                  False
# P4P                            False                  False
#
#              ABp[xaplrvd]aapppa  ABalap[xaplrvd]papa|ABp[xaplrvd]paaappa  \
# ABALAAAALAL               False                                    False
# ABALAAAALAR               False                                    False
# ABALAAAALPA               False                                    False
# ABALAAAALPP               False                                    False
# ABALAAAARLA               False                                    False
# ...                         ...                                      ...
# MSPPPPAP                  False                                    False
# MSPPPPPA                  False                                    False
# MSPPPPPP                  False                                    False
# P4A                       False                                    False
# P4P                       False                                    False
#
#              D[xaplrvd][xaplrvd]a[xaplrvd]  ABalppppa|ABpraaapa  \
# ABALAAAALAL                          False                False
# ABALAAAALAR                          False                False
# ABALAAAALPA                          False                False
# ABALAAAALPP                          False                False
# ABALAAAARLA                          False                False
# ...                                    ...                  ...
# MSPPPPAP                             False                False
# MSPPPPPA                             False                False
# MSPPPPPP                             False                False
# P4A                                  False                False
# P4P                                  False                False
#
#              MS[xaplrvd]pppp[xaplrvd]  ...  C[xaplrvd]a  \
# ABALAAAALAL                     False  ...        False
# ABALAAAALAR                     False  ...        False
# ABALAAAALPA                     False  ...        False
# ABALAAAALPP                     False  ...        False
# ABALAAAARLA                     False  ...        False
# ...                               ...  ...          ...
# MSPPPPAP                        False  ...        False
# MSPPPPPA                         True  ...        False
# MSPPPPPP                         True  ...        False
# P4A                             False  ...        False
# P4P                             False  ...        False
#
#              ABalaa[xaplrvd]|ABalap[xaplrvd]a  MS[xaplrvd]a  ABarpp[xaplrvd]a  \
# ABALAAAALAL                             False         False             False
# ABALAAAALAR                             False         False             False
# ABALAAAALPA                             False         False             False
# ABALAAAALPP                             False         False             False
# ABALAAAARLA                             False         False             False
# ...                                       ...           ...               ...
# MSPPPPAP                                False         False             False
# MSPPPPPA                                False         False             False
# MSPPPPPP                                False         False             False
# P4A                                     False         False             False
# P4P                                     False         False             False
#
#              MS[xaplrvd]  ABalaa[xaplrvd]  ABp[xaplrvd]app  C[xaplrvd]ap  \
# ABALAAAALAL        False            False            False         False
# ABALAAAALAR        False            False            False         False
# ABALAAAALPA        False            False            False         False
# ABALAAAALPP        False            False            False         False
# ABALAAAARLA        False            False            False         False
# ...                  ...              ...              ...           ...
# MSPPPPAP           False            False            False         False
# MSPPPPPA           False            False            False         False
# MSPPPPPP           False            False            False         False
# P4A                False            False            False         False
# P4P                False            False            False         False
#
#              ABp[xaplrvd]apa  ABp[xaplrvd]pa
# ABALAAAALAL            False           False
# ABALAAAALAR            False           False
# ABALAAAALPA            False           False
# ABALAAAALPP            False           False
# ABALAAAARLA            False           False
# ...                      ...             ...
# MSPPPPAP               False           False
# MSPPPPPA               False           False
# MSPPPPPP               False           False
# P4A                    False           False
# P4P                    False           False
#
# [668 rows x 499 columns]

# %%
meta_regex_lineages_joined_set_to_leaf = {}
matched_leaves = set()
for reg in meta_regex_lineages_joined_set:
  if leaf_matches[reg].any():
    leaf = leaf_matches.index[np.argmax(leaf_matches[reg])]
    meta_regex_lineages_joined_set_to_leaf[reg] = leaf
    matched_leaves.add(leaf)

# drop matched columns
leaf_matches = leaf_matches[leaf_matches.columns[~leaf_matches.columns.isin(meta_regex_lineages_joined_set_to_leaf.keys())]]
# drop matched rows
leaf_matches = leaf_matches.iloc[~leaf_matches.index.isin(matched_leaves)]
leaf_matches
# Out:
#              MS[xaplrvd]apaap  D[xaplrvd]ap  ABalpappaa|ABarapapaa  \
# ABALAAAALAR             False         False                  False
# ABALAAAALPA             False         False                  False
# ABALAAAALPP             False         False                  False
# ABALAAAARLA             False         False                  False
# ABALAAAARRA             False         False                  False
# ...                       ...           ...                    ...
# MSPPPPAP                False         False                  False
# MSPPPPPA                False         False                  False
# MSPPPPPP                False         False                  False
# P4A                     False         False                  False
# P4P                     False         False                  False
#
#              ABalap[xaplrvd]papa|ABp[xaplrvd]paaappa  ABalppppa|ABpraaapa  \
# ABALAAAALAR                                    False                False
# ABALAAAALPA                                    False                False
# ABALAAAALPP                                    False                False
# ABALAAAARLA                                    False                False
# ABALAAAARRA                                    False                False
# ...                                              ...                  ...
# MSPPPPAP                                       False                False
# MSPPPPPA                                       False                False
# MSPPPPPP                                       False                False
# P4A                                            False                False
# P4P                                            False                False
#
#              ABaraaaapa  ABp[xaplrvd]ppapaa  ABalpaapa|ABaraaapa  \
# ABALAAAALAR       False               False                False
# ABALAAAALPA       False               False                False
# ABALAAAALPP       False               False                False
# ABALAAAARLA       False               False                False
# ABALAAAARRA       False               False                False
# ...                 ...                 ...                  ...
# MSPPPPAP          False               False                False
# MSPPPPPA          False               False                False
# MSPPPPPP          False               False                False
# P4A               False               False                False
# P4P               False               False                False
#
#              ABalaaaala|ABalaapaaa  ABp[xaplrvd]paaaaa  ...  C[xaplrvd]a  \
# ABALAAAALAR                  False               False  ...        False
# ABALAAAALPA                  False               False  ...        False
# ABALAAAALPP                  False               False  ...        False
# ABALAAAARLA                  False               False  ...        False
# ABALAAAARRA                  False               False  ...        False
# ...                            ...                 ...  ...          ...
# MSPPPPAP                     False               False  ...        False
# MSPPPPPA                     False               False  ...        False
# MSPPPPPP                     False               False  ...        False
# P4A                          False               False  ...        False
# P4P                          False               False  ...        False
#
#              ABalaa[xaplrvd]|ABalap[xaplrvd]a  MS[xaplrvd]a  ABarpp[xaplrvd]a  \
# ABALAAAALAR                             False         False             False
# ABALAAAALPA                             False         False             False
# ABALAAAALPP                             False         False             False
# ABALAAAARLA                             False         False             False
# ABALAAAARRA                             False         False             False
# ...                                       ...           ...               ...
# MSPPPPAP                                False         False             False
# MSPPPPPA                                False         False             False
# MSPPPPPP                                False         False             False
# P4A                                     False         False             False
# P4P                                     False         False             False
#
#              MS[xaplrvd]  ABalaa[xaplrvd]  ABp[xaplrvd]app  C[xaplrvd]ap  \
# ABALAAAALAR        False            False            False         False
# ABALAAAALPA        False            False            False         False
# ABALAAAALPP        False            False            False         False
# ABALAAAARLA        False            False            False         False
# ABALAAAARRA        False            False            False         False
# ...                  ...              ...              ...           ...
# MSPPPPAP           False            False            False         False
# MSPPPPPA           False            False            False         False
# MSPPPPPP           False            False            False         False
# P4A                False            False            False         False
# P4P                False            False            False         False
#
#              ABp[xaplrvd]apa  ABp[xaplrvd]pa
# ABALAAAALAR            False           False
# ABALAAAALPA            False           False
# ABALAAAALPP            False           False
# ABALAAAARLA            False           False
# ABALAAAARRA            False           False
# ...                      ...             ...
# MSPPPPAP               False           False
# MSPPPPPA               False           False
# MSPPPPPP               False           False
# P4A                    False           False
# P4P                    False           False
#
# [520 rows x 349 columns]

# %%
leaf_matches.any().any()  # no matches left
# Out:
# False

# %%
to_prune =  leaf_matches.index.values
pruned_tree.prune_taxa_with_labels(to_prune)
pruned_tree.update_taxon_namespace()
leaf_labels = np.array([t.taxon.label for t in pruned_tree.leaf_nodes()])
print('to_prune', len(to_prune), 'remaining', len(leaf_labels))
# Out:
# to_prune 520 remaining 335

# %%
unmatched_meta_regex = leaf_matches.columns
leaf_labels = pd.Series(leaf_labels).sort_values()
leaf_matches = pd.DataFrame(np.zeros((len(leaf_labels), len(unmatched_meta_regex))).astype(bool))
leaf_matches.columns = unmatched_meta_regex
leaf_matches.index = leaf_labels
for rexp in tqdm(unmatched_meta_regex):
  leaf_matches[rexp] = leaf_labels.str.fullmatch(str.upper(rexp)).values
leaf_matches
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 349/349 [00:00<00:00, 4585.98it/s]
#              MS[xaplrvd]apaap  D[xaplrvd]ap  ABalpappaa|ABarapapaa  \
# ABALAAAALAL             False         False                  False
# ABALAAAALP              False         False                  False
# ABALAAAARLP             False         False                  False
# ABALAAAARR              False         False                  False
# ABALAAAPALL             False         False                  False
# ...                       ...           ...                    ...
# MSPPPAA                 False         False                  False
# MSPPPAP                 False         False                  False
# MSPPPPA                 False         False                  False
# MSPPPPP                 False         False                  False
# P4                      False         False                  False
#
#              ABalap[xaplrvd]papa|ABp[xaplrvd]paaappa  ABalppppa|ABpraaapa  \
# ABALAAAALAL                                    False                False
# ABALAAAALP                                     False                False
# ABALAAAARLP                                    False                False
# ABALAAAARR                                     False                False
# ABALAAAPALL                                    False                False
# ...                                              ...                  ...
# MSPPPAA                                        False                False
# MSPPPAP                                        False                False
# MSPPPPA                                        False                False
# MSPPPPP                                        False                False
# P4                                             False                False
#
#              ABaraaaapa  ABp[xaplrvd]ppapaa  ABalpaapa|ABaraaapa  \
# ABALAAAALAL       False               False                False
# ABALAAAALP        False               False                False
# ABALAAAARLP       False               False                False
# ABALAAAARR        False               False                False
# ABALAAAPALL       False               False                False
# ...                 ...                 ...                  ...
# MSPPPAA           False               False                False
# MSPPPAP           False               False                False
# MSPPPPA           False               False                False
# MSPPPPP           False               False                False
# P4                False               False                False
#
#              ABalaaaala|ABalaapaaa  ABp[xaplrvd]paaaaa  ...  C[xaplrvd]a  \
# ABALAAAALAL                  False               False  ...        False
# ABALAAAALP                   False               False  ...        False
# ABALAAAARLP                  False               False  ...        False
# ABALAAAARR                   False               False  ...        False
# ABALAAAPALL                  False               False  ...        False
# ...                            ...                 ...  ...          ...
# MSPPPAA                      False               False  ...        False
# MSPPPAP                      False               False  ...        False
# MSPPPPA                      False               False  ...        False
# MSPPPPP                      False               False  ...        False
# P4                           False               False  ...        False
#
#              ABalaa[xaplrvd]|ABalap[xaplrvd]a  MS[xaplrvd]a  ABarpp[xaplrvd]a  \
# ABALAAAALAL                             False         False             False
# ABALAAAALP                              False         False             False
# ABALAAAARLP                             False         False             False
# ABALAAAARR                              False         False             False
# ABALAAAPALL                             False         False             False
# ...                                       ...           ...               ...
# MSPPPAA                                 False         False             False
# MSPPPAP                                 False         False             False
# MSPPPPA                                 False         False             False
# MSPPPPP                                 False         False             False
# P4                                      False         False             False
#
#              MS[xaplrvd]  ABalaa[xaplrvd]  ABp[xaplrvd]app  C[xaplrvd]ap  \
# ABALAAAALAL        False            False            False         False
# ABALAAAALP         False            False            False         False
# ABALAAAARLP        False            False            False         False
# ABALAAAARR         False            False            False         False
# ABALAAAPALL        False            False            False         False
# ...                  ...              ...              ...           ...
# MSPPPAA            False            False            False         False
# MSPPPAP            False            False            False         False
# MSPPPPA            False            False            False         False
# MSPPPPP            False            False            False         False
# P4                 False            False            False         False
#
#              ABp[xaplrvd]apa  ABp[xaplrvd]pa
# ABALAAAALAL            False           False
# ABALAAAALP             False           False
# ABALAAAARLP            False           False
# ABALAAAARR             False           False
# ABALAAAPALL            False           False
# ...                      ...             ...
# MSPPPAA                False           False
# MSPPPAP                False           False
# MSPPPPA                False           False
# MSPPPPP                False           False
# P4                     False           False
#
# [335 rows x 349 columns]

# %%
for reg in leaf_matches.columns:
  if leaf_matches[reg].any():
    leaf = leaf_matches.index[np.argmax(leaf_matches[reg])]
    meta_regex_lineages_joined_set_to_leaf[reg] = leaf
    matched_leaves.add(leaf)

# drop matched columns
leaf_matches = leaf_matches[leaf_matches.columns[~leaf_matches.columns.isin(meta_regex_lineages_joined_set_to_leaf.keys())]]
# drop matched rows
leaf_matches = leaf_matches.iloc[~leaf_matches.index.isin(matched_leaves)]
leaf_matches
# Out:
#               MS[xaplrvd]apaap  ABalpappaa|ABarapapaa  ABalppppa|ABpraaapa  \
# ABALAAAPPL               False                  False                False
# ABALAAPAAP               False                  False                False
# ABALAPAPPAA              False                  False                False
# ABALAPPPPAA              False                  False                False
# ABALPAPPAAP              False                  False                False
# ABALPPAPPPA              False                  False                False
# ABARAAAAAP               False                  False                False
# ABARAAPPPAA              False                  False                False
# ABARAAPPPP               False                  False                False
# ABARAPAAAA               False                  False                False
# ABARAPAAAP               False                  False                False
# ABARAPAAPA               False                  False                False
# ABARAPAAPP               False                  False                False
# ABARAPAPAAP              False                  False                False
# ABARAPAPPA               False                  False                False
# ABARAPAPPP               False                  False                False
# ABARAPPAPAP              False                  False                False
# ABARAPPAPP               False                  False                False
# ABARAPPPAA               False                  False                False
# ABARAPPPAP               False                  False                False
# ABARAPPPPPA              False                  False                False
# ABPLAAAAAA               False                  False                False
# ABPLAPAPPPPA             False                  False                False
# ABPLPAAAPPA              False                  False                False
# ABPLPAAPPPP              False                  False                False
# ABPLPPAPAAA              False                  False                False
# ABPRAAAAAP               False                  False                False
# ABPRAPAPAA               False                  False                False
# ABPRAPAPPPPA             False                  False                False
# ABPRPAAAPA               False                  False                False
# ABPRPAAAPPA              False                  False                False
# ABPRPAAPPPP              False                  False                False
# ABPRPAPAPP               False                  False                False
# ABPRPPAAPP               False                  False                False
# ABPRPPAPAAA              False                  False                False
# ABPRPPAPAP               False                  False                False
# ABPRPPAPPA               False                  False                False
# ABPRPPAPPP               False                  False                False
# ABPRPPPAAPA              False                  False                False
# ABPRPPPAPA               False                  False                False
# ABPRPPPPPA               False                  False                False
# ABPRPPPPPP               False                  False                False
# CPAAP                    False                  False                False
# DPAA                     False                  False                False
# DPPA                     False                  False                False
# EARAA                    False                  False                False
# EPRA                     False                  False                False
# EPRPP                    False                  False                False
# MSPAPAAA                 False                  False                False
# MSPAPAAPA                False                  False                False
# MSPPAAAA                 False                  False                False
# MSPPAPAA                 False                  False                False
# P4                       False                  False                False
#
#               ABp[xaplrvd]ppapaa  ABalpaapa|ABaraaapa  ABp[xaplrvd]ppppap  \
# ABALAAAPPL                 False                False               False
# ABALAAPAAP                 False                False               False
# ABALAPAPPAA                False                False               False
# ABALAPPPPAA                False                False               False
# ABALPAPPAAP                False                False               False
# ABALPPAPPPA                False                False               False
# ABARAAAAAP                 False                False               False
# ABARAAPPPAA                False                False               False
# ABARAAPPPP                 False                False               False
# ABARAPAAAA                 False                False               False
# ABARAPAAAP                 False                False               False
# ABARAPAAPA                 False                False               False
# ABARAPAAPP                 False                False               False
# ABARAPAPAAP                False                False               False
# ABARAPAPPA                 False                False               False
# ABARAPAPPP                 False                False               False
# ABARAPPAPAP                False                False               False
# ABARAPPAPP                 False                False               False
# ABARAPPPAA                 False                False               False
# ABARAPPPAP                 False                False               False
# ABARAPPPPPA                False                False               False
# ABPLAAAAAA                 False                False               False
# ABPLAPAPPPPA               False                False               False
# ABPLPAAAPPA                False                False               False
# ABPLPAAPPPP                False                False               False
# ABPLPPAPAAA                False                False               False
# ABPRAAAAAP                 False                False               False
# ABPRAPAPAA                 False                False               False
# ABPRAPAPPPPA               False                False               False
# ABPRPAAAPA                 False                False               False
# ABPRPAAAPPA                False                False               False
# ABPRPAAPPPP                False                False               False
# ABPRPAPAPP                 False                False               False
# ABPRPPAAPP                 False                False               False
# ABPRPPAPAAA                False                False               False
# ABPRPPAPAP                 False                False               False
# ABPRPPAPPA                 False                False               False
# ABPRPPAPPP                 False                False               False
# ABPRPPPAAPA                False                False               False
# ABPRPPPAPA                 False                False               False
# ABPRPPPPPA                 False                False               False
# ABPRPPPPPP                 False                False               False
# CPAAP                      False                False               False
# DPAA                       False                False               False
# DPPA                       False                False               False
# EARAA                      False                False               False
# EPRA                       False                False               False
# EPRPP                      False                False               False
# MSPAPAAA                   False                False               False
# MSPAPAAPA                  False                False               False
# MSPPAAAA                   False                False               False
# MSPPAPAA                   False                False               False
# P4                         False                False               False
#
#               ABprpappap  ABalaapppp|ABalapaapp  C[xaplrvd]ppa  \
# ABALAAAPPL         False                  False          False
# ABALAAPAAP         False                  False          False
# ABALAPAPPAA        False                  False          False
# ABALAPPPPAA        False                  False          False
# ABALPAPPAAP        False                  False          False
# ABALPPAPPPA        False                  False          False
# ABARAAAAAP         False                  False          False
# ABARAAPPPAA        False                  False          False
# ABARAAPPPP         False                  False          False
# ABARAPAAAA         False                  False          False
# ABARAPAAAP         False                  False          False
# ABARAPAAPA         False                  False          False
# ABARAPAAPP         False                  False          False
# ABARAPAPAAP        False                  False          False
# ABARAPAPPA         False                  False          False
# ABARAPAPPP         False                  False          False
# ABARAPPAPAP        False                  False          False
# ABARAPPAPP         False                  False          False
# ABARAPPPAA         False                  False          False
# ABARAPPPAP         False                  False          False
# ABARAPPPPPA        False                  False          False
# ABPLAAAAAA         False                  False          False
# ABPLAPAPPPPA       False                  False          False
# ABPLPAAAPPA        False                  False          False
# ABPLPAAPPPP        False                  False          False
# ABPLPPAPAAA        False                  False          False
# ABPRAAAAAP         False                  False          False
# ABPRAPAPAA         False                  False          False
# ABPRAPAPPPPA       False                  False          False
# ABPRPAAAPA         False                  False          False
# ABPRPAAAPPA        False                  False          False
# ABPRPAAPPPP        False                  False          False
# ABPRPAPAPP         False                  False          False
# ABPRPPAAPP         False                  False          False
# ABPRPPAPAAA        False                  False          False
# ABPRPPAPAP         False                  False          False
# ABPRPPAPPA         False                  False          False
# ABPRPPAPPP         False                  False          False
# ABPRPPPAAPA        False                  False          False
# ABPRPPPAPA         False                  False          False
# ABPRPPPPPA         False                  False          False
# ABPRPPPPPP         False                  False          False
# CPAAP              False                  False          False
# DPAA               False                  False          False
# DPPA               False                  False          False
# EARAA              False                  False          False
# EPRA               False                  False          False
# EPRPP              False                  False          False
# MSPAPAAA           False                  False          False
# MSPAPAAPA          False                  False          False
# MSPPAAAA           False                  False          False
# MSPPAPAA           False                  False          False
# P4                 False                  False          False
#
#               ABp[xaplrvd]ppppa  ...  C[xaplrvd]a  \
# ABALAAAPPL                False  ...        False
# ABALAAPAAP                False  ...        False
# ABALAPAPPAA               False  ...        False
# ABALAPPPPAA               False  ...        False
# ABALPAPPAAP               False  ...        False
# ABALPPAPPPA               False  ...        False
# ABARAAAAAP                False  ...        False
# ABARAAPPPAA               False  ...        False
# ABARAAPPPP                False  ...        False
# ABARAPAAAA                False  ...        False
# ABARAPAAAP                False  ...        False
# ABARAPAAPA                False  ...        False
# ABARAPAAPP                False  ...        False
# ABARAPAPAAP               False  ...        False
# ABARAPAPPA                False  ...        False
# ABARAPAPPP                False  ...        False
# ABARAPPAPAP               False  ...        False
# ABARAPPAPP                False  ...        False
# ABARAPPPAA                False  ...        False
# ABARAPPPAP                False  ...        False
# ABARAPPPPPA               False  ...        False
# ABPLAAAAAA                False  ...        False
# ABPLAPAPPPPA              False  ...        False
# ABPLPAAAPPA               False  ...        False
# ABPLPAAPPPP               False  ...        False
# ABPLPPAPAAA               False  ...        False
# ABPRAAAAAP                False  ...        False
# ABPRAPAPAA                False  ...        False
# ABPRAPAPPPPA              False  ...        False
# ABPRPAAAPA                False  ...        False
# ABPRPAAAPPA               False  ...        False
# ABPRPAAPPPP               False  ...        False
# ABPRPAPAPP                False  ...        False
# ABPRPPAAPP                False  ...        False
# ABPRPPAPAAA               False  ...        False
# ABPRPPAPAP                False  ...        False
# ABPRPPAPPA                False  ...        False
# ABPRPPAPPP                False  ...        False
# ABPRPPPAAPA               False  ...        False
# ABPRPPPAPA                False  ...        False
# ABPRPPPPPA                False  ...        False
# ABPRPPPPPP                False  ...        False
# CPAAP                     False  ...        False
# DPAA                      False  ...        False
# DPPA                      False  ...        False
# EARAA                     False  ...        False
# EPRA                      False  ...        False
# EPRPP                     False  ...        False
# MSPAPAAA                  False  ...        False
# MSPAPAAPA                 False  ...        False
# MSPPAAAA                  False  ...        False
# MSPPAPAA                  False  ...        False
# P4                        False  ...        False
#
#               ABalaa[xaplrvd]|ABalap[xaplrvd]a  MS[xaplrvd]a  \
# ABALAAAPPL                               False         False
# ABALAAPAAP                               False         False
# ABALAPAPPAA                              False         False
# ABALAPPPPAA                              False         False
# ABALPAPPAAP                              False         False
# ABALPPAPPPA                              False         False
# ABARAAAAAP                               False         False
# ABARAAPPPAA                              False         False
# ABARAAPPPP                               False         False
# ABARAPAAAA                               False         False
# ABARAPAAAP                               False         False
# ABARAPAAPA                               False         False
# ABARAPAAPP                               False         False
# ABARAPAPAAP                              False         False
# ABARAPAPPA                               False         False
# ABARAPAPPP                               False         False
# ABARAPPAPAP                              False         False
# ABARAPPAPP                               False         False
# ABARAPPPAA                               False         False
# ABARAPPPAP                               False         False
# ABARAPPPPPA                              False         False
# ABPLAAAAAA                               False         False
# ABPLAPAPPPPA                             False         False
# ABPLPAAAPPA                              False         False
# ABPLPAAPPPP                              False         False
# ABPLPPAPAAA                              False         False
# ABPRAAAAAP                               False         False
# ABPRAPAPAA                               False         False
# ABPRAPAPPPPA                             False         False
# ABPRPAAAPA                               False         False
# ABPRPAAAPPA                              False         False
# ABPRPAAPPPP                              False         False
# ABPRPAPAPP                               False         False
# ABPRPPAAPP                               False         False
# ABPRPPAPAAA                              False         False
# ABPRPPAPAP                               False         False
# ABPRPPAPPA                               False         False
# ABPRPPAPPP                               False         False
# ABPRPPPAAPA                              False         False
# ABPRPPPAPA                               False         False
# ABPRPPPPPA                               False         False
# ABPRPPPPPP                               False         False
# CPAAP                                    False         False
# DPAA                                     False         False
# DPPA                                     False         False
# EARAA                                    False         False
# EPRA                                     False         False
# EPRPP                                    False         False
# MSPAPAAA                                 False         False
# MSPAPAAPA                                False         False
# MSPPAAAA                                 False         False
# MSPPAPAA                                 False         False
# P4                                       False         False
#
#               ABarpp[xaplrvd]a  MS[xaplrvd]  ABalaa[xaplrvd]  ABp[xaplrvd]app  \
# ABALAAAPPL               False        False            False            False
# ABALAAPAAP               False        False            False            False
# ABALAPAPPAA              False        False            False            False
# ABALAPPPPAA              False        False            False            False
# ABALPAPPAAP              False        False            False            False
# ABALPPAPPPA              False        False            False            False
# ABARAAAAAP               False        False            False            False
# ABARAAPPPAA              False        False            False            False
# ABARAAPPPP               False        False            False            False
# ABARAPAAAA               False        False            False            False
# ABARAPAAAP               False        False            False            False
# ABARAPAAPA               False        False            False            False
# ABARAPAAPP               False        False            False            False
# ABARAPAPAAP              False        False            False            False
# ABARAPAPPA               False        False            False            False
# ABARAPAPPP               False        False            False            False
# ABARAPPAPAP              False        False            False            False
# ABARAPPAPP               False        False            False            False
# ABARAPPPAA               False        False            False            False
# ABARAPPPAP               False        False            False            False
# ABARAPPPPPA              False        False            False            False
# ABPLAAAAAA               False        False            False            False
# ABPLAPAPPPPA             False        False            False            False
# ABPLPAAAPPA              False        False            False            False
# ABPLPAAPPPP              False        False            False            False
# ABPLPPAPAAA              False        False            False            False
# ABPRAAAAAP               False        False            False            False
# ABPRAPAPAA               False        False            False            False
# ABPRAPAPPPPA             False        False            False            False
# ABPRPAAAPA               False        False            False            False
# ABPRPAAAPPA              False        False            False            False
# ABPRPAAPPPP              False        False            False            False
# ABPRPAPAPP               False        False            False            False
# ABPRPPAAPP               False        False            False            False
# ABPRPPAPAAA              False        False            False            False
# ABPRPPAPAP               False        False            False            False
# ABPRPPAPPA               False        False            False            False
# ABPRPPAPPP               False        False            False            False
# ABPRPPPAAPA              False        False            False            False
# ABPRPPPAPA               False        False            False            False
# ABPRPPPPPA               False        False            False            False
# ABPRPPPPPP               False        False            False            False
# CPAAP                    False        False            False            False
# DPAA                     False        False            False            False
# DPPA                     False        False            False            False
# EARAA                    False        False            False            False
# EPRA                     False        False            False            False
# EPRPP                    False        False            False            False
# MSPAPAAA                 False        False            False            False
# MSPAPAAPA                False        False            False            False
# MSPPAAAA                 False        False            False            False
# MSPPAPAA                 False        False            False            False
# P4                       False        False            False            False
#
#               C[xaplrvd]ap  ABp[xaplrvd]apa  ABp[xaplrvd]pa
# ABALAAAPPL           False            False           False
# ABALAAPAAP           False            False           False
# ABALAPAPPAA          False            False           False
# ABALAPPPPAA          False            False           False
# ABALPAPPAAP          False            False           False
# ABALPPAPPPA          False            False           False
# ABARAAAAAP           False            False           False
# ABARAAPPPAA          False            False           False
# ABARAAPPPP           False            False           False
# ABARAPAAAA           False            False           False
# ABARAPAAAP           False            False           False
# ABARAPAAPA           False            False           False
# ABARAPAAPP           False            False           False
# ABARAPAPAAP          False            False           False
# ABARAPAPPA           False            False           False
# ABARAPAPPP           False            False           False
# ABARAPPAPAP          False            False           False
# ABARAPPAPP           False            False           False
# ABARAPPPAA           False            False           False
# ABARAPPPAP           False            False           False
# ABARAPPPPPA          False            False           False
# ABPLAAAAAA           False            False           False
# ABPLAPAPPPPA         False            False           False
# ABPLPAAAPPA          False            False           False
# ABPLPAAPPPP          False            False           False
# ABPLPPAPAAA          False            False           False
# ABPRAAAAAP           False            False           False
# ABPRAPAPAA           False            False           False
# ABPRAPAPPPPA         False            False           False
# ABPRPAAAPA           False            False           False
# ABPRPAAAPPA          False            False           False
# ABPRPAAPPPP          False            False           False
# ABPRPAPAPP           False            False           False
# ABPRPPAAPP           False            False           False
# ABPRPPAPAAA          False            False           False
# ABPRPPAPAP           False            False           False
# ABPRPPAPPA           False            False           False
# ABPRPPAPPP           False            False           False
# ABPRPPPAAPA          False            False           False
# ABPRPPPAPA           False            False           False
# ABPRPPPPPA           False            False           False
# ABPRPPPPPP           False            False           False
# CPAAP                False            False           False
# DPAA                 False            False           False
# DPPA                 False            False           False
# EARAA                False            False           False
# EPRA                 False            False           False
# EPRPP                False            False           False
# MSPAPAAA             False            False           False
# MSPAPAAPA            False            False           False
# MSPPAAAA             False            False           False
# MSPPAPAA             False            False           False
# P4                   False            False           False
#
# [53 rows x 215 columns]

# %%
leaf_matches.any().any()  # no matches left
# Out:
# False

# %%
to_prune =  leaf_matches.index.values
pruned_tree.prune_taxa_with_labels(to_prune)
pruned_tree.update_taxon_namespace()
leaf_labels = np.array([t.taxon.label for t in pruned_tree.leaf_nodes()])
print('to_prune', len(to_prune), 'remaining', len(leaf_labels))
# Out:
# to_prune 53 remaining 295

# %%
unmatched_meta_regex = leaf_matches.columns
leaf_labels = pd.Series(leaf_labels).sort_values()
leaf_matches = pd.DataFrame(np.zeros((len(leaf_labels), len(unmatched_meta_regex))).astype(bool))
leaf_matches.columns = unmatched_meta_regex
leaf_matches.index = leaf_labels
for rexp in tqdm(unmatched_meta_regex):
  leaf_matches[rexp] = leaf_labels.str.fullmatch(str.upper(rexp)).values
leaf_matches
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 215/215 [00:00<00:00, 4835.44it/s]
#              MS[xaplrvd]apaap  ABalpappaa|ABarapapaa  ABalppppa|ABpraaapa  \
# ABALAAAALAL             False                  False                False
# ABALAAAALP              False                  False                False
# ABALAAAARLP             False                  False                False
# ABALAAAARR              False                  False                False
# ABALAAAPALL             False                  False                False
# ...                       ...                    ...                  ...
# MSPPAPP                 False                  False                False
# MSPPPAA                 False                  False                False
# MSPPPAP                 False                  False                False
# MSPPPPA                 False                  False                False
# MSPPPPP                 False                  False                False
#
#              ABp[xaplrvd]ppapaa  ABalpaapa|ABaraaapa  ABp[xaplrvd]ppppap  \
# ABALAAAALAL               False                False               False
# ABALAAAALP                False                False               False
# ABALAAAARLP               False                False               False
# ABALAAAARR                False                False               False
# ABALAAAPALL               False                False               False
# ...                         ...                  ...                 ...
# MSPPAPP                   False                False               False
# MSPPPAA                   False                False               False
# MSPPPAP                   False                False               False
# MSPPPPA                   False                False               False
# MSPPPPP                   False                False               False
#
#              ABprpappap  ABalaapppp|ABalapaapp  C[xaplrvd]ppa  \
# ABALAAAALAL       False                  False          False
# ABALAAAALP        False                  False          False
# ABALAAAARLP       False                  False          False
# ABALAAAARR        False                  False          False
# ABALAAAPALL       False                  False          False
# ...                 ...                    ...            ...
# MSPPAPP           False                  False          False
# MSPPPAA           False                  False          False
# MSPPPAP           False                  False          False
# MSPPPPA           False                  False          False
# MSPPPPP           False                  False          False
#
#              ABp[xaplrvd]ppppa  ...  C[xaplrvd]a  \
# ABALAAAALAL              False  ...        False
# ABALAAAALP               False  ...        False
# ABALAAAARLP              False  ...        False
# ABALAAAARR               False  ...        False
# ABALAAAPALL              False  ...        False
# ...                        ...  ...          ...
# MSPPAPP                  False  ...        False
# MSPPPAA                  False  ...        False
# MSPPPAP                  False  ...        False
# MSPPPPA                  False  ...        False
# MSPPPPP                  False  ...        False
#
#              ABalaa[xaplrvd]|ABalap[xaplrvd]a  MS[xaplrvd]a  ABarpp[xaplrvd]a  \
# ABALAAAALAL                             False         False             False
# ABALAAAALP                              False         False             False
# ABALAAAARLP                             False         False             False
# ABALAAAARR                              False         False             False
# ABALAAAPALL                             False         False             False
# ...                                       ...           ...               ...
# MSPPAPP                                 False         False             False
# MSPPPAA                                 False         False             False
# MSPPPAP                                 False         False             False
# MSPPPPA                                 False         False             False
# MSPPPPP                                 False         False             False
#
#              MS[xaplrvd]  ABalaa[xaplrvd]  ABp[xaplrvd]app  C[xaplrvd]ap  \
# ABALAAAALAL        False            False            False         False
# ABALAAAALP         False            False            False         False
# ABALAAAARLP        False            False            False         False
# ABALAAAARR         False            False            False         False
# ABALAAAPALL        False            False            False         False
# ...                  ...              ...              ...           ...
# MSPPAPP            False            False            False         False
# MSPPPAA            False            False            False         False
# MSPPPAP            False            False            False         False
# MSPPPPA            False            False            False         False
# MSPPPPP            False            False            False         False
#
#              ABp[xaplrvd]apa  ABp[xaplrvd]pa
# ABALAAAALAL            False           False
# ABALAAAALP             False           False
# ABALAAAARLP            False           False
# ABALAAAARR             False           False
# ABALAAAPALL            False           False
# ...                      ...             ...
# MSPPAPP                False           False
# MSPPPAA                False           False
# MSPPPAP                False           False
# MSPPPPA                False           False
# MSPPPPP                False           False
#
# [295 rows x 215 columns]

# %%
for reg in leaf_matches.columns:
  if leaf_matches[reg].any():
    leaf = leaf_matches.index[np.argmax(leaf_matches[reg])]
    meta_regex_lineages_joined_set_to_leaf[reg] = leaf
    matched_leaves.add(leaf)

# drop matched columns
leaf_matches = leaf_matches[leaf_matches.columns[~leaf_matches.columns.isin(meta_regex_lineages_joined_set_to_leaf.keys())]]
# drop matched rows
leaf_matches = leaf_matches.iloc[~leaf_matches.index.isin(matched_leaves)]
leaf_matches  # nothing left
# Out:
# Empty DataFrame
# Columns: [MS[xaplrvd]apaap, ABalpappaa|ABarapapaa, ABalppppa|ABpraaapa, ABp[xaplrvd]ppapaa, ABalpaapa|ABaraaapa, ABp[xaplrvd]ppppap, ABprpappap, ABalaapppp|ABalapaapp, C[xaplrvd]ppa, ABp[xaplrvd]ppppa, ABalappaap, Caapa, ABalapppaa, ABp[xaplrvd]apppap, Z2|Z3:pseudotime_bin_2, ABp[xaplrvd]paappp, ABp[xaplrvd]ppaaa, MSaaapp, ABprpappaa, ABalpppap|ABpraaaap, C[xaplrvd]app, ABp[xaplrvd]paaapp, MS[xaplrvd]appp, C[xaplrvd]pap, ABarpaaaa, D[xaplrvd]p, MSaaaaap, ABalpppppp|ABpraaappp, ABprpapppa, D[xaplrvd]a, ABp[xaplrvd]apappp, ABalppappp|ABarappppp, C[xaplrvd]paa, MS[xaplrvd]papa, MSpappa, ABalppppap|ABpraaapap, ABp[xaplrvd]paapa, ABalpaappp, D[xaplrvd]pp, ABarpapaap|ABplaaaaap, MSaaaaa, ABaraap[xaplrvd]a, ABalaapaa, ABalpapapa|ABarappapa, MSaaaaaa, ABp[xaplrvd]apppa, ABp[xaplrvd]ppaap, ABarpapaa|ABplaaaaa, ABp[xaplrvd]papaa, ABalpppapp|ABpraaaapp, ABaraap[xaplrvd]pa, MSaaaap, ABp[xaplrvd]papap, ABalppppp|ABpraaapp, ABp[xaplrvd]apapa, ABalpaapp|ABaraaapp, ABalpappa|ABarapapa, MS[xaplrvd]aapa, ABp[xaplrvd]ppaaaa, ABalapaaa|ABalappap, ABarpp[xaplrvd]ap, C[xaplrvd]pa, ABp[xaplrvd]apaaap, ABplpapppa, MSppaap, ABalap[xaplrvd]ppa, ABalpappap, ABaraaaaa, ABp[xaplrvd]pppaa, ABalap[xaplrvd]pap|ABp[xaplrvd]paaapp, C[xaplrvd]ppp, ABp[xaplrvd]apaaa, ABarapapap, ABalaaap[xaplrvd], ABp[xaplrvd]aapapp, MS[xaplrvd]paaa, ABprpappa, ABalaapap|ABalppaap, ABp[xaplrvd]aapaa, ABp[xaplrvd]apapppp, ABalaappa|ABalppaaa, MSaaaapp, ABalppapp|ABarapppp, MS[xaplrvd]paa, ABp[xaplrvd]pppap, MSpaaap, MS[xaplrvd]apap, ABalap[xaplrvd]pp, ABp[xaplrvd]paapp, ABplpappp, ABarpaaap, MS[xaplrvd]app, C[xaplrvd]pp, ABp[xaplrvd]apaaaa, ABp[xaplrvd]paaaa, MS[xaplrvd]pap, ABalappaa, ABalaaaar, ABp[xaplrvd]pppaap, ABplpapppp, ...]
# Index: []
#
# [0 rows x 202 columns]

# %%
len(set(meta_regex_lineages_joined_set_to_leaf.values()))
# Out:
# 295

# %%
meta_regex_lineages_joined
# Out:
# 0                       MS[xaplrvd]pappp
# 1                       MS[xaplrvd]apaap
# 3                           D[xaplrvd]ap
# 4                ABalpppapav|ABpraaaapav
# 5                  ABalpappaa|ABarapapaa
#                       ...
# 89659                        ABplpappppp
# 89681    ABplpappppp|ABp[xaplrvd]ppppaap
# 89682    ABplpappppp|ABp[xaplrvd]ppppaap
# 89690                ABplppppap[xaplrvd]
# 89692                        ABprpppaaaa
# Length: 47798, dtype: object

# %%
cell_to_leaf_df = pd.DataFrame(meta_regex_lineages_joined, columns=['regex_joined'])
cell_to_leaf_df.index.name = 'og_idx'
cell_to_leaf_df = cell_to_leaf_df.loc[cell_to_leaf_df['regex_joined'].isin(meta_regex_lineages_joined_set_to_leaf.keys())]
cell_to_leaf_df['leaf'] = cell_to_leaf_df['regex_joined'].replace(meta_regex_lineages_joined_set_to_leaf)
cell_to_leaf_df
# Out:
#                                    regex_joined         leaf
# og_idx
# 0                              MS[xaplrvd]pappp     MSAPAPPP
# 3                                  D[xaplrvd]ap         DPAP
# 4                       ABalpppapav|ABpraaaapav  ABALPPPAPAV
# 6                            ABp[xaplrvd]aapppa   ABPLAAPPPA
# 7       ABalap[xaplrvd]papa|ABp[xaplrvd]paaappa  ABALAPPPAPA
# ...                                         ...          ...
# 89659                               ABplpappppp  ABPLPAPPPPP
# 89681           ABplpappppp|ABp[xaplrvd]ppppaap  ABPLPAPPPPP
# 89682           ABplpappppp|ABp[xaplrvd]ppppaap  ABPLPAPPPPP
# 89690                       ABplppppap[xaplrvd]  ABPLPPPPAPA
# 89692                               ABprpppaaaa  ABPRPPPAAAA
#
# [34609 rows x 2 columns]

# %%
pruned_tree.write(path=f'{data_path}/preprocessed/worm_avg_leaves_pruned.nwk', schema='newick')

# %% [markdown]
# # Gene expression pre-processing

# %%
# R sparse matrix
expression_adata = mmread(f'{data_path}/GSE126954_gene_by_cell_count_matrix.txt')
print(expression_adata.shape)

all_gene_names = pd.read_csv(f'{data_path}/GSE126954_gene_annotation.csv')
all_gene_names = all_gene_names.id.values
print(len(all_gene_names))

expression_df = pd.DataFrame(expression_adata.toarray()[:, cell_to_leaf_df.index].T,
                             index=cell_to_leaf_df.index, columns=all_gene_names)
expression_df['leaf'] = cell_to_leaf_df['leaf']
expression_df
# Out:
# (20222, 89701)
# 20222
#         WBGene00010957  WBGene00010958  WBGene00010959  WBGene00010960  \
# og_idx
# 0                    5               0               0               7
# 3                   26               1              14              52
# 4                    4               0               2               7
# 6                   73               0              38              76
# 7                    7               0               2               0
# ...                ...             ...             ...             ...
# 89659               12               1               4              12
# 89681                8               0               0               2
# 89682               16               1               2               6
# 89690               17               0               0              11
# 89692               16               1               0              10
#
#         WBGene00010961  WBGene00000829  WBGene00010962  WBGene00010963  \
# og_idx
# 0                    3               5               8               3
# 3                    5              17              38               6
# 4                    0               0               1               2
# 6                    9              17              49              11
# 7                    1               0               1               0
# ...                ...             ...             ...             ...
# 89659                1               5              10               1
# 89681                0               0               0               0
# 89682                2               5              18               3
# 89690                2               5              14               1
# 89692                0               9              17               1
#
#         WBGene00010964  WBGene00010965  ...  WBGene00001780  WBGene00001782  \
# og_idx                                  ...
# 0                    5               4  ...               0               0
# 3                   17              17  ...               0               0
# 4                    3               7  ...               0               0
# 6                   31              39  ...               0               0
# 7                    7               3  ...               0               0
# ...                ...             ...  ...             ...             ...
# 89659                3              11  ...               0               0
# 89681                0               3  ...               0               0
# 89682                7               9  ...               0               0
# 89690               12              13  ...               0               0
# 89692                6               4  ...               0               0
#
#         WBGene00001783  WBGene00021598  WBGene00021597  WBGene00021596  \
# og_idx
# 0                    0               0               0               0
# 3                    0               0               0               0
# 4                    0               0               0               0
# 6                    0               0               0               0
# 7                    0               0               0               0
# ...                ...             ...             ...             ...
# 89659                0               0               0               0
# 89681                0               0               0               0
# 89682                0               0               0               0
# 89690                0               0               0               0
# 89692                0               0               0               0
#
#         WBGene00021595  WBGene00021594  WBGene00007064         leaf
# og_idx
# 0                    1               0               0     MSAPAPPP
# 3                    0               0               0         DPAP
# 4                    0               0               0  ABALPPPAPAV
# 6                    0               0               0   ABPLAAPPPA
# 7                    0               0               0  ABALAPPPAPA
# ...                ...             ...             ...          ...
# 89659                0               0               1  ABPLPAPPPPP
# 89681                0               0               0  ABPLPAPPPPP
# 89682                0               0               0  ABPLPAPPPPP
# 89690                0               0               0  ABPLPPPPAPA
# 89692                0               0               0  ABPRPPPAAAA
#
# [34609 rows x 20223 columns]

# %%
leaf_expression = expression_df.groupby(['leaf']).mean()
leaf_expression.to_csv(f'{data_path}/preprocessed/worm_avg_leaves_cells.txt', index=True, columns=[], header=False)
leaf_expression
# Out:
#              WBGene00010957  WBGene00010958  WBGene00010959  WBGene00010960  \
# leaf
# ABALAAAALAL        4.441176        0.147059        1.205882        2.794118
# ABALAAAALP         7.612613        0.450450        2.738739        7.135135
# ABALAAAARLP        4.830579        0.289256        1.714876        2.896694
# ABALAAAARR         8.717742        0.282258        2.790323        7.266129
# ABALAAAPALL        4.458015        0.335878        1.419847        2.404580
# ...                     ...             ...             ...             ...
# MSPPAPP           19.070352        0.753769        6.884422       24.060302
# MSPPPAA           15.343284        0.626866        5.676617       17.975124
# MSPPPAP           12.065116        0.451163        4.706977       13.925581
# MSPPPPA           17.880282        0.683099        6.415493       24.014085
# MSPPPPP           17.694030        0.679104        6.511194       22.417910
#
#              WBGene00010961  WBGene00000829  WBGene00010962  WBGene00010963  \
# leaf
# ABALAAAALAL        0.411765        0.617647        3.617647        0.647059
# ABALAAAALP         0.882883        1.990991        7.882883        1.306306
# ABALAAAARLP        0.442149        1.342975        3.859504        0.772727
# ABALAAAARR         0.766129        2.241935        9.185484        1.145161
# ABALAAAPALL        0.427481        1.282443        3.328244        0.580153
# ...                     ...             ...             ...             ...
# MSPPAPP            1.839196        4.437186       20.507538        2.648241
# MSPPPAA            1.437811        4.109453       17.791045        2.154229
# MSPPPAP            1.241860        2.855814       13.320930        1.739535
# MSPPPPA            1.971831        4.485915       21.788732        2.683099
# MSPPPPP            1.626866        4.656716       20.537313        2.485075
#
#              WBGene00010964  WBGene00010965  ...  WBGene00013175  \
# leaf                                         ...
# ABALAAAALAL        2.147059        2.000000  ...             0.0
# ABALAAAALP         3.738739        4.972973  ...             0.0
# ABALAAAARLP        2.628099        3.826446  ...             0.0
# ABALAAAARR         3.814516        6.290323  ...             0.0
# ABALAAAPALL        2.137405        3.748092  ...             0.0
# ...                     ...             ...  ...             ...
# MSPPAPP            7.914573       11.110553  ...             0.0
# MSPPPAA            7.079602       10.557214  ...             0.0
# MSPPPAP            5.390698        8.655814  ...             0.0
# MSPPPPA            7.753521       10.654930  ...             0.0
# MSPPPPP            7.485075       11.500000  ...             0.0
#
#              WBGene00001780  WBGene00001782  WBGene00001783  WBGene00021598  \
# leaf
# ABALAAAALAL             0.0             0.0        0.000000             0.0
# ABALAAAALP              0.0             0.0        0.000000             0.0
# ABALAAAARLP             0.0             0.0        0.000000             0.0
# ABALAAAARR              0.0             0.0        0.000000             0.0
# ABALAAAPALL             0.0             0.0        0.000000             0.0
# ...                     ...             ...             ...             ...
# MSPPAPP                 0.0             0.0        0.000000             0.0
# MSPPPAA                 0.0             0.0        0.014925             0.0
# MSPPPAP                 0.0             0.0        0.000000             0.0
# MSPPPPA                 0.0             0.0        0.000000             0.0
# MSPPPPP                 0.0             0.0        0.000000             0.0
#
#              WBGene00021597  WBGene00021596  WBGene00021595  WBGene00021594  \
# leaf
# ABALAAAALAL        0.000000        0.029412        0.029412        0.000000
# ABALAAAALP         0.000000        0.000000        0.036036        0.000000
# ABALAAAARLP        0.004132        0.004132        0.024793        0.000000
# ABALAAAARR         0.008065        0.000000        0.024194        0.000000
# ABALAAAPALL        0.137405        0.000000        0.015267        0.007634
# ...                     ...             ...             ...             ...
# MSPPAPP            0.005025        0.015075        0.256281        0.000000
# MSPPPAA            0.014925        0.000000        0.213930        0.000000
# MSPPPAP            0.009302        0.000000        0.130233        0.000000
# MSPPPPA            0.007042        0.000000        0.197183        0.000000
# MSPPPPP            0.003731        0.007463        0.250000        0.000000
#
#              WBGene00007064
# leaf
# ABALAAAALAL        0.058824
# ABALAAAALP         0.018018
# ABALAAAARLP        0.016529
# ABALAAAARR         0.048387
# ABALAAAPALL        0.053435
# ...                     ...
# MSPPAPP            0.040201
# MSPPPAA            0.029851
# MSPPPAP            0.023256
# MSPPPPA            0.028169
# MSPPPPP            0.037313
#
# [295 rows x 20222 columns]

# %%
# there are no duplicates!
unq, count = np.unique(leaf_expression.values, axis=0, return_counts=True)
len(unq[count>1])
# Out:
# 0

# %%
# remove rare genes
print(leaf_expression.shape)
leaf_expression = leaf_expression.iloc[:, ((leaf_expression > 0).sum(axis=0) >= 10).values.flatten()]
print(leaf_expression.shape)
keep_gene_names = leaf_expression.columns
gene_counts = leaf_expression.values

# L1 normalization on cells to [0, 10000]
gene_counts = gene_counts / gene_counts.sum(axis=1).reshape(-1, 1)
gene_counts *= 10000
# log2(1 + x) tranform
gene_counts = np.log2(1 + gene_counts)

df = pd.DataFrame(gene_counts)
df.columns = keep_gene_names
df.to_csv(f'{data_path}/preprocessed/worm_avg_leaves_normalized_log_counts.txt', index=False)
df
# Out:
# (295, 20222)
# (295, 13918)
#      WBGene00010957  WBGene00010958  WBGene00010959  WBGene00010960  \
# 0          5.679704        1.413686        3.872454        5.027651
# 1          5.697354        2.004026        4.271124        5.605763
# 2          5.596016        1.939782        4.155122        4.878004
# 3          5.749838        1.438237        4.162172        5.492416
# 4          5.630195        2.219177        4.040549        4.764241
# ..              ...             ...             ...             ...
# 290        6.484244        2.169628        5.042565        6.816221
# 291        6.226306        2.006483        4.824248        6.451877
# 292        6.195602        1.888819        4.868080        6.399865
# 293        6.382175        2.052573        4.934020        6.803261
# 294        6.366877        2.045870        4.954323        6.704578
#
#      WBGene00010961  WBGene00000829  WBGene00010962  WBGene00010963  \
# 0          2.500720        2.998108        5.390207        3.056991
# 1          2.786995        3.838892        5.746732        3.282798
# 2          2.415693        3.824702        5.279720        3.100548
# 3          2.495987        3.866062        5.823873        2.988646
# 4          2.499130        3.903070        5.218408        2.870934
# ..              ...             ...             ...             ...
# 290        3.253647        4.432817        6.587937        3.732639
# 291        2.985914        4.377454        6.437197        3.507342
# 292        3.077431        4.178853        6.336598        3.513884
# 293        3.334613        4.438021        6.664282        3.740560
# 294        3.086848        4.489127        6.579440        3.638177
#
#      WBGene00010964  WBGene00010965  ...  WBGene00001777  WBGene00001787  \
# 0          4.660888        4.562714  ...             0.0        0.000000
# 1          4.700039        5.097754  ...             0.0        0.084368
# 2          4.742622        5.267631  ...             0.0        0.000000
# 3          4.591440        5.289326  ...             0.0        0.000000
# 4          4.600937        5.385456  ...             0.0        0.000000
# ..              ...             ...  ...             ...             ...
# 290        5.238033        5.716342  ...             0.0        0.000000
# 291        5.132758        5.695638  ...             0.0        0.000000
# 292        5.057472        5.724234  ...             0.0        0.000000
# 293        5.199144        5.647008  ...             0.0        0.000000
# 294        5.149350        5.754633  ...             0.0        0.024594
#
#      WBGene00001779  WBGene00001783  WBGene00021598  WBGene00021597  \
# 0               0.0        0.000000             0.0        0.000000
# 1               0.0        0.000000             0.0        0.000000
# 2               0.0        0.000000             0.0        0.057306
# 3               0.0        0.000000             0.0        0.068814
# 4               0.0        0.000000             0.0        1.319473
# ..              ...             ...             ...             ...
# 290             0.0        0.000000             0.0        0.033267
# 291             0.0        0.100113             0.0        0.100113
# 292             0.0        0.000000             0.0        0.078253
# 293             0.0        0.000000             0.0        0.046083
# 294             0.0        0.000000             0.0        0.024594
#
#      WBGene00021596  WBGene00021595  WBGene00021594  WBGene00007064
# 0          0.414497        0.414497        0.000000        0.736101
# 1          0.000000        0.311380        0.000000        0.164075
# 2          0.057306        0.313973        0.000000        0.216715
# 3          0.000000        0.197315        0.000000        0.370861
# 4          0.000000        0.221808        0.115163        0.661458
# ..              ...             ...             ...             ...
# 290        0.097586        1.130723        0.000000        0.246855
# 291        0.000000        1.021449        0.000000        0.193728
# 292        0.000000        0.832153        0.000000        0.188206
# 293        0.000000        0.932690        0.000000        0.176110
# 294        0.048776        1.105656        0.000000        0.228893
#
# [295 rows x 13918 columns]

# %% [markdown]
# # Cell types

# %%
cell_types = cell_to_leaf_df.copy()
cell_types['type'] = cell_meta.iloc[cell_to_leaf_df.index]['cell.type']
cell_types = cell_types.groupby('leaf')['type'].unique()
cell_types
# Out:
# leaf
# ABALAAAALAL                                 [nan]
# ABALAAAALP          [nan, ABarpaaa_lineage, Glia]
# ABALAAAARLP                                 [nan]
# ABALAAAARR     [nan, Pharyngeal_intestinal_valve]
# ABALAAAPALL                                [Glia]
#                               ...
# MSPPAPP                   [Body_wall_muscle, nan]
# MSPPPAA                              [nan, Z1_Z4]
# MSPPPAP              [nan, GLR, Body_wall_muscle]
# MSPPPPA                        [Body_wall_muscle]
# MSPPPPP                   [Body_wall_muscle, nan]
# Name: type, Length: 295, dtype: object

# %%
def f(types):
  if len(types) == 0:
    return np.nan
  if types[0] is None or types[0] == np.nan:
    return f(types[1:])
  return types[0]

cell_types = pd.DataFrame(cell_types.map(f))
cell_types
# Out:
#                          type
# leaf
# ABALAAAALAL               NaN
# ABALAAAALP                NaN
# ABALAAAARLP               NaN
# ABALAAAARR                NaN
# ABALAAAPALL              Glia
# ...                       ...
# MSPPAPP      Body_wall_muscle
# MSPPPAA                   NaN
# MSPPPAP                   NaN
# MSPPPPA      Body_wall_muscle
# MSPPPPP      Body_wall_muscle
#
# [295 rows x 1 columns]

# %%
cell_types.to_csv(f'{data_path}/preprocessed/worm_avg_leaves_cell_types.csv')
